# %% [markdown]
# ## Colmap 3D Reconstruction
# This notebook provides steps on running Colmap Sparse Reconstruction in Colab

# %% [markdown]
# Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Install Colmap

# %%
# !apt-get update
# !apt-get install -y colmap ffmpeg
# !nvidia-smi
# !colmap -h
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,801 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,063 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,750 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,254 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,587 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,561 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,040 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,351 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,741 kB]
# Fetched 32.5 MB in 3s (9,602 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   libamd2 libcamd2 libccolamd2 libceres2 libcholmod3 libcolamd2 libcxsparse3
#   libevdev2 libfreeimage3 libgflags2.2 libgoogle-glog0v5 libgudev-1.0-0
#   libinput-bin libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libraw20
#   libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common libwacom9
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0
#   qt5-gtk-platformtheme qttranslations5-l10n
# Suggested packages:
#   qt5-image-formats-plugins qtwayland5
# The following NEW packages will be installed:
#   colmap libamd2 libcamd2 libccolamd2 libceres2 libcholmod3 libcolamd2
#   libcxsparse3 libevdev2 libfreeimage3 libgflags2.2 libgoogle-glog0v5
#   libgudev-1.0-0 libinput-bin libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1
#   libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5
#   libraw20 libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common
#   libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0
#   qt5-gtk-platformtheme qttranslations5-l10n
# 0 upgraded, 42 newly installed, 0 to remove and 37 not upgraded.
# Need to get 17.5 MB of archives.
# After this operation, 68.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libamd2 amd64 1:5.10.1+dfsg-4build1 [21.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcamd2 amd64 1:5.10.1+dfsg-4build1 [23.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libccolamd2 amd64 1:5.10.1+dfsg-4build1 [25.2 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis5 amd64 5.1.0.dfsg-7build2 [181 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcholmod3 amd64 1:5.10.1+dfsg-4build1 [346 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcxsparse3 amd64 1:5.10.1+dfsg-4build1 [70.8 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags2.2 amd64 2.2.2-2 [78.1 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog0v5 amd64 0.5.0+really0.4.0-2 [60.3 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspqr2 amd64 1:5.10.1+dfsg-4build1 [71.6 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres2 amd64 2.0.0+dfsg1-5 [834 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraw20 amd64 0.20.2-2ubuntu2.22.04.2 [342 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libfreeimage3 amd64 3.18.0+ds2-6ubuntu5.1 [294 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 colmap amd64 3.7-2 [2,998 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Fetched 17.5 MB in 2s (8,979 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libqt5core5a:amd64.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../00-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../01-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../02-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../03-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../04-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../05-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../06-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../07-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../08-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../09-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../10-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../11-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../12-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../13-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../14-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../15-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../16-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../17-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../18-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../19-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../20-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../21-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../22-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../23-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../24-libamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../25-libcamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../26-libccolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../27-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../28-libmetis5_5.1.0.dfsg-7build2_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../29-libcholmod3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../30-libcxsparse3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../31-libgflags2.2_2.2.2-2_amd64.deb ...
# Unpacking libgflags2.2 (2.2.2-2) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../32-libgoogle-glog0v5_0.5.0+really0.4.0-2_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../33-libspqr2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libceres2.
# Preparing to unpack .../34-libceres2_2.0.0+dfsg1-5_amd64.deb ...
# Unpacking libceres2 (2.0.0+dfsg1-5) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../35-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libraw20:amd64.
# Preparing to unpack .../36-libraw20_0.20.2-2ubuntu2.22.04.2_amd64.deb ...
# Unpacking libraw20:amd64 (0.20.2-2ubuntu2.22.04.2) ...
# Selecting previously unselected package libfreeimage3:amd64.
# Preparing to unpack .../37-libfreeimage3_3.18.0+ds2-6ubuntu5.1_amd64.deb ...
# Unpacking libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Selecting previously unselected package colmap.
# Preparing to unpack .../38-colmap_3.7-2_amd64.deb ...
# Unpacking colmap (3.7-2) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../39-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../40-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../41-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libraw20:amd64 (0.20.2-2ubuntu2.22.04.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libgflags2.2 (2.2.2-2) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Setting up libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libceres2 (2.0.0+dfsg1-5) ...
# Setting up colmap (3.7-2) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# /bin/bash: line 1: nvidia-smi: command not found
# COLMAP 3.7 -- Structure-from-Motion and Multi-View Stereo
#               (Commit Unknown on Unknown without CUDA)
#
# Usage:
#   colmap [command] [options]
#
# Documentation:
#   https://colmap.github.io/
#
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
#
# Available commands:
#   help
#   gui
#   automatic_reconstructor
#   bundle_adjuster
#   color_extractor
#   database_cleaner
#   database_creator
#   database_merger
#   delaunay_mesher
#   exhaustive_matcher
#   feature_extractor
#   feature_importer
#   hierarchical_mapper
#   image_deleter
#   image_filterer
#   image_rectifier
#   image_registrator
#   image_undistorter
#   image_undistorter_standalone
#   mapper
#   matches_importer
#   model_aligner
#   model_analyzer
#   model_comparer
#   model_converter
#   model_cropper
#   model_merger
#   model_orientation_aligner
#   model_splitter
#   model_transformer
#   patch_match_stereo
#   point_filtering
#   point_triangulator
#   poisson_mesher
#   project_generator
#   rig_bundle_adjuster
#   sequential_matcher
#   spatial_matcher
#   stereo_fusion
#   transitive_matcher
#   vocab_tree_builder
#   vocab_tree_matcher
#   vocab_tree_retriever

# %% [markdown]
# Import libraries

# %%
import cv2
import numpy as np
import os
import shutil

# %% [markdown]
# Preprocess the frames (those particular settings worked well with the 10SOM282 video)

# %%
def preprocess_frame(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    denoised = cv2.fastNlMeansDenoising(gray, h=10)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced = clahe.apply(denoised)
    gamma = 1.2
    lut = np.array([((i / 255.0) ** (1.0 / gamma)) * 255 for i in np.arange(256)]).astype("uint8")
    gamma_corrected = cv2.LUT(enhanced, lut)
    edges = cv2.Laplacian(gamma_corrected, cv2.CV_64F)
    edges = cv2.convertScaleAbs(edges)
    enhanced_edges = cv2.addWeighted(gamma_corrected, 0.8, edges, 0.2, 0)
    sharpening_kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    sharpened = cv2.filter2D(enhanced_edges, -1, sharpening_kernel)
    return sharpened

def process_video_fragment(video_path, output_folder, start_time, end_time, sample_fps=10, fragment_number=1):
    cap = cv2.VideoCapture(video_path)
    actual_fps = cap.get(cv2.CAP_PROP_FPS)
    os.makedirs(output_folder, exist_ok=True)

    print(f"\nProcessing fragment: {start_time}s to {end_time}s")
    start_frame = int(start_time * actual_fps)
    end_frame = int(end_time * actual_fps)
    frame_interval = max(1, int(actual_fps / sample_fps))

    frag_folder = os.path.join(output_folder, f"fragment_{fragment_number}")
    os.makedirs(frag_folder, exist_ok=True)

    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
    frame_idx = start_frame
    saved_idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret or frame_idx > end_frame:
            break

        if frame_idx % frame_interval == 0:
            processed = preprocess_frame(frame)
            base_fname = f"{frag_folder}/frame_{saved_idx:04d}"
            cv2.imwrite(f"{base_fname}.png", processed)
            saved_idx += 1
        frame_idx += 1

    cap.release()

# Define the input and output directories
video_file = "/content/drive/MyDrive/10SOM282.mp4"
output_dir = "/content/drive/MyDrive/processed_frames"

# Define the time constraints of the segment you want to reconstruct
start_time = 9 * 60 + 21
end_time = 9 * 60 + 42
fragment_number = 1

# Process the video fragment
process_video_fragment(video_file, output_dir, start_time, end_time, fragment_number)
# Out:
# Processing fragment: 561s to 582s

# %% [markdown]
# Set up the COLMAP directory structure and copy the preprocessed files

# %%
# Set up COLMAP project structure
project_dir = "/content/drive/MyDrive/colmap_project"
images_dir = os.path.join(project_dir, "images")
sparse_dir = os.path.join(project_dir, "sparse")
dense_dir = os.path.join(project_dir, "dense")

os.makedirs(images_dir, exist_ok=True)
os.makedirs(sparse_dir, exist_ok=True)
os.makedirs(dense_dir, exist_ok=True)

# Source directory
source_dir = f"/content/drive/MyDrive/processed_frames/fragment_{fragment_number}"

# List and sort files
all_files = sorted(os.listdir(source_dir))

# Copy selected files
for filename in all_files:
    src = os.path.join(source_dir, filename)
    dst = os.path.join(images_dir, filename)
    if os.path.isfile(src):
        shutil.copy2(src, dst)

# %% [markdown]
# Extract the features from the frames with SIFT

# %%
# !colmap feature_extractor \
    --database_path /content/drive/MyDrive/colmap_project/database.db \
    --image_path /content/drive/MyDrive/colmap_project/images \
    --ImageReader.single_camera 1 \
    --ImageReader.camera_model PINHOLE \
    --SiftExtraction.use_gpu 0
# Out:
# WARNING: Your current options use the maximum number of threads on the machine to extract features. Exracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/315]
#   Name:            frame_0000.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7310
# Processed file [2/315]
#   Name:            frame_0001.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6738
# Processed file [3/315]
#   Name:            frame_0002.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5596
# Processed file [4/315]
#   Name:            frame_0003.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5890
# Processed file [5/315]
#   Name:            frame_0004.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6385
# Processed file [6/315]
#   Name:            frame_0005.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6632
# Processed file [7/315]
#   Name:            frame_0006.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6897
# Processed file [8/315]
#   Name:            frame_0007.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6140
# Processed file [9/315]
#   Name:            frame_0008.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6505
# Processed file [10/315]
#   Name:            frame_0009.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8101
# Processed file [11/315]
#   Name:            frame_0010.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9707
# Processed file [12/315]
#   Name:            frame_0011.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10106
# Processed file [13/315]
#   Name:            frame_0012.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11073
# Processed file [14/315]
#   Name:            frame_0013.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10327
# Processed file [15/315]
#   Name:            frame_0014.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10685
# Processed file [16/315]
#   Name:            frame_0015.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10227
# Processed file [17/315]
#   Name:            frame_0016.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10602
# Processed file [18/315]
#   Name:            frame_0017.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5864
# Processed file [19/315]
#   Name:            frame_0018.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        4776
# Processed file [20/315]
#   Name:            frame_0019.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5499
# Processed file [21/315]
#   Name:            frame_0020.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6433
# Processed file [22/315]
#   Name:            frame_0021.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7404
# Processed file [23/315]
#   Name:            frame_0022.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9076
# Processed file [24/315]
#   Name:            frame_0023.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9644
# Processed file [25/315]
#   Name:            frame_0024.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9873
# Processed file [26/315]
#   Name:            frame_0025.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10271
# Processed file [27/315]
#   Name:            frame_0026.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9965
# Processed file [28/315]
#   Name:            frame_0027.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11136
# Processed file [29/315]
#   Name:            frame_0028.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10962
# Processed file [30/315]
#   Name:            frame_0029.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11270
# Processed file [31/315]
#   Name:            frame_0030.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11596
# Processed file [32/315]
#   Name:            frame_0031.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10584
# Processed file [33/315]
#   Name:            frame_0032.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9614
# Processed file [34/315]
#   Name:            frame_0033.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10283
# Processed file [35/315]
#   Name:            frame_0034.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9808
# Processed file [36/315]
#   Name:            frame_0035.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10661
# Processed file [37/315]
#   Name:            frame_0036.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10920
# Processed file [38/315]
#   Name:            frame_0037.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12032
# Processed file [39/315]
#   Name:            frame_0038.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11642
# Processed file [40/315]
#   Name:            frame_0039.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11748
# Processed file [41/315]
#   Name:            frame_0040.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11586
# Processed file [42/315]
#   Name:            frame_0041.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11329
# Processed file [43/315]
#   Name:            frame_0042.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11228
# Processed file [44/315]
#   Name:            frame_0043.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10961
# Processed file [45/315]
#   Name:            frame_0044.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11265
# Processed file [46/315]
#   Name:            frame_0045.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11883
# Processed file [47/315]
#   Name:            frame_0046.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11649
# Processed file [48/315]
#   Name:            frame_0047.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11295
# Processed file [49/315]
#   Name:            frame_0048.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11274
# Processed file [50/315]
#   Name:            frame_0049.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11142
# Processed file [51/315]
#   Name:            frame_0050.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11149
# Processed file [52/315]
#   Name:            frame_0051.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11466
# Processed file [53/315]
#   Name:            frame_0052.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11021
# Processed file [54/315]
#   Name:            frame_0053.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10448
# Processed file [55/315]
#   Name:            frame_0054.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10711
# Processed file [56/315]
#   Name:            frame_0055.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10293
# Processed file [57/315]
#   Name:            frame_0056.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11238
# Processed file [58/315]
#   Name:            frame_0057.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10451
# Processed file [59/315]
#   Name:            frame_0058.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9952
# Processed file [60/315]
#   Name:            frame_0059.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11081
# Processed file [61/315]
#   Name:            frame_0060.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11213
# Processed file [62/315]
#   Name:            frame_0061.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10694
# Processed file [63/315]
#   Name:            frame_0062.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9840
# Processed file [64/315]
#   Name:            frame_0063.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11059
# Processed file [65/315]
#   Name:            frame_0064.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10753
# Processed file [66/315]
#   Name:            frame_0065.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10397
# Processed file [67/315]
#   Name:            frame_0066.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10842
# Processed file [68/315]
#   Name:            frame_0067.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10689
# Processed file [69/315]
#   Name:            frame_0068.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10045
# Processed file [70/315]
#   Name:            frame_0069.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10189
# Processed file [71/315]
#   Name:            frame_0070.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9805
# Processed file [72/315]
#   Name:            frame_0071.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10784
# Processed file [73/315]
#   Name:            frame_0072.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10548
# Processed file [74/315]
#   Name:            frame_0074.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10641
# Processed file [75/315]
#   Name:            frame_0073.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9751
# Processed file [76/315]
#   Name:            frame_0075.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10600
# Processed file [77/315]
#   Name:            frame_0076.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10297
# Processed file [78/315]
#   Name:            frame_0077.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11120
# Processed file [79/315]
#   Name:            frame_0078.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10926
# Processed file [80/315]
#   Name:            frame_0079.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11054
# Processed file [81/315]
#   Name:            frame_0080.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10726
# Processed file [82/315]
#   Name:            frame_0081.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11227
# Processed file [83/315]
#   Name:            frame_0082.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10131
# Processed file [84/315]
#   Name:            frame_0083.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9901
# Processed file [85/315]
#   Name:            frame_0084.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10688
# Processed file [86/315]
#   Name:            frame_0085.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10863
# Processed file [87/315]
#   Name:            frame_0086.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10647
# Processed file [88/315]
#   Name:            frame_0087.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11013
# Processed file [89/315]
#   Name:            frame_0088.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10539
# Processed file [90/315]
#   Name:            frame_0090.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7218
# Processed file [91/315]
#   Name:            frame_0089.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10004
# Processed file [92/315]
#   Name:            frame_0091.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10386
# Processed file [93/315]
#   Name:            frame_0092.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12046
# Processed file [94/315]
#   Name:            frame_0093.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11904
# Processed file [95/315]
#   Name:            frame_0094.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11841
# Processed file [96/315]
#   Name:            frame_0095.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11894
# Processed file [97/315]
#   Name:            frame_0096.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12564
# Processed file [98/315]
#   Name:            frame_0097.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12131
# Processed file [99/315]
#   Name:            frame_0098.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11937
# Processed file [100/315]
#   Name:            frame_0099.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12073
# Processed file [101/315]
#   Name:            frame_0100.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11993
# Processed file [102/315]
#   Name:            frame_0101.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11817
# Processed file [103/315]
#   Name:            frame_0102.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12411
# Processed file [104/315]
#   Name:            frame_0103.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12059
# Processed file [105/315]
#   Name:            frame_0104.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11779
# Processed file [106/315]
#   Name:            frame_0105.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12553
# Processed file [107/315]
#   Name:            frame_0106.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12262
# Processed file [108/315]
#   Name:            frame_0108.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12672
# Processed file [109/315]
#   Name:            frame_0107.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12587
# Processed file [110/315]
#   Name:            frame_0109.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12503
# Processed file [111/315]
#   Name:            frame_0110.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11942
# Processed file [112/315]
#   Name:            frame_0111.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12110
# Processed file [113/315]
#   Name:            frame_0112.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12623
# Processed file [114/315]
#   Name:            frame_0113.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12004
# Processed file [115/315]
#   Name:            frame_0114.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9879
# Processed file [116/315]
#   Name:            frame_0115.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12535
# Processed file [117/315]
#   Name:            frame_0116.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12536
# Processed file [118/315]
#   Name:            frame_0117.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9764
# Processed file [119/315]
#   Name:            frame_0118.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12880
# Processed file [120/315]
#   Name:            frame_0119.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12775
# Processed file [121/315]
#   Name:            frame_0120.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10020
# Processed file [122/315]
#   Name:            frame_0121.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9791
# Processed file [123/315]
#   Name:            frame_0122.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12898
# Processed file [124/315]
#   Name:            frame_0123.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12744
# Processed file [125/315]
#   Name:            frame_0124.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12245
# Processed file [126/315]
#   Name:            frame_0125.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11528
# Processed file [127/315]
#   Name:            frame_0126.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12211
# Processed file [128/315]
#   Name:            frame_0127.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12912
# Processed file [129/315]
#   Name:            frame_0128.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12333
# Processed file [130/315]
#   Name:            frame_0129.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        12461
# Processed file [131/315]
#   Name:            frame_0130.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11853
# Processed file [132/315]
#   Name:            frame_0131.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11103
# Processed file [133/315]
#   Name:            frame_0132.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11890
# Processed file [134/315]
#   Name:            frame_0133.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10930
# Processed file [135/315]
#   Name:            frame_0134.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10076
# Processed file [136/315]
#   Name:            frame_0135.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10423
# Processed file [137/315]
#   Name:            frame_0136.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9778
# Processed file [138/315]
#   Name:            frame_0137.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10275
# Processed file [139/315]
#   Name:            frame_0138.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10157
# Processed file [140/315]
#   Name:            frame_0139.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9941
# Processed file [141/315]
#   Name:            frame_0140.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11178
# Processed file [142/315]
#   Name:            frame_0141.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10368
# Processed file [143/315]
#   Name:            frame_0142.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10253
# Processed file [144/315]
#   Name:            frame_0143.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10093
# Processed file [145/315]
#   Name:            frame_0144.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10418
# Processed file [146/315]
#   Name:            frame_0145.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10132
# Processed file [147/315]
#   Name:            frame_0146.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11282
# Processed file [148/315]
#   Name:            frame_0147.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9791
# Processed file [149/315]
#   Name:            frame_0148.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10678
# Processed file [150/315]
#   Name:            frame_0149.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9883
# Processed file [151/315]
#   Name:            frame_0150.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10038
# Processed file [152/315]
#   Name:            frame_0151.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10226
# Processed file [153/315]
#   Name:            frame_0152.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9405
# Processed file [154/315]
#   Name:            frame_0153.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10014
# Processed file [155/315]
#   Name:            frame_0154.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9686
# Processed file [156/315]
#   Name:            frame_0155.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9129
# Processed file [157/315]
#   Name:            frame_0156.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9502
# Processed file [158/315]
#   Name:            frame_0157.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8325
# Processed file [159/315]
#   Name:            frame_0158.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8089
# Processed file [160/315]
#   Name:            frame_0159.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8541
# Processed file [161/315]
#   Name:            frame_0160.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8437
# Processed file [162/315]
#   Name:            frame_0161.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8393
# Processed file [163/315]
#   Name:            frame_0162.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8399
# Processed file [164/315]
#   Name:            frame_0163.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6836
# Processed file [165/315]
#   Name:            frame_0164.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7489
# Processed file [166/315]
#   Name:            frame_0165.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8489
# Processed file [167/315]
#   Name:            frame_0166.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8651
# Processed file [168/315]
#   Name:            frame_0167.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9393
# Processed file [169/315]
#   Name:            frame_0168.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9742
# Processed file [170/315]
#   Name:            frame_0169.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9545
# Processed file [171/315]
#   Name:            frame_0170.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9214
# Processed file [172/315]
#   Name:            frame_0171.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9784
# Processed file [173/315]
#   Name:            frame_0172.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10300
# Processed file [174/315]
#   Name:            frame_0173.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9943
# Processed file [175/315]
#   Name:            frame_0174.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10450
# Processed file [176/315]
#   Name:            frame_0175.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10112
# Processed file [177/315]
#   Name:            frame_0177.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9541
# Processed file [178/315]
#   Name:            frame_0176.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9667
# Processed file [179/315]
#   Name:            frame_0179.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6622
# Processed file [180/315]
#   Name:            frame_0178.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8353
# Processed file [181/315]
#   Name:            frame_0181.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5495
# Processed file [182/315]
#   Name:            frame_0180.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5679
# Processed file [183/315]
#   Name:            frame_0182.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        4377
# Processed file [184/315]
#   Name:            frame_0183.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        4980
# Processed file [185/315]
#   Name:            frame_0184.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5336
# Processed file [186/315]
#   Name:            frame_0185.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5415
# Processed file [187/315]
#   Name:            frame_0186.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5420
# Processed file [188/315]
#   Name:            frame_0187.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5019
# Processed file [189/315]
#   Name:            frame_0188.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5184
# Processed file [190/315]
#   Name:            frame_0189.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5682
# Processed file [191/315]
#   Name:            frame_0190.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5902
# Processed file [192/315]
#   Name:            frame_0191.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6471
# Processed file [193/315]
#   Name:            frame_0192.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6824
# Processed file [194/315]
#   Name:            frame_0193.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7590
# Processed file [195/315]
#   Name:            frame_0194.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8668
# Processed file [196/315]
#   Name:            frame_0195.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9801
# Processed file [197/315]
#   Name:            frame_0196.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10543
# Processed file [198/315]
#   Name:            frame_0197.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10545
# Processed file [199/315]
#   Name:            frame_0198.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10673
# Processed file [200/315]
#   Name:            frame_0199.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10602
# Processed file [201/315]
#   Name:            frame_0200.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10697
# Processed file [202/315]
#   Name:            frame_0201.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11384
# Processed file [203/315]
#   Name:            frame_0202.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11588
# Processed file [204/315]
#   Name:            frame_0203.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11476
# Processed file [205/315]
#   Name:            frame_0204.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11516
# Processed file [206/315]
#   Name:            frame_0205.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11233
# Processed file [207/315]
#   Name:            frame_0206.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10729
# Processed file [208/315]
#   Name:            frame_0207.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11526
# Processed file [209/315]
#   Name:            frame_0208.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10763
# Processed file [210/315]
#   Name:            frame_0209.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10723
# Processed file [211/315]
#   Name:            frame_0210.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11302
# Processed file [212/315]
#   Name:            frame_0211.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11047
# Processed file [213/315]
#   Name:            frame_0212.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10892
# Processed file [214/315]
#   Name:            frame_0213.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10814
# Processed file [215/315]
#   Name:            frame_0214.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10314
# Processed file [216/315]
#   Name:            frame_0215.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10295
# Processed file [217/315]
#   Name:            frame_0216.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11027
# Processed file [218/315]
#   Name:            frame_0217.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11220
# Processed file [219/315]
#   Name:            frame_0218.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10657
# Processed file [220/315]
#   Name:            frame_0219.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11098
# Processed file [221/315]
#   Name:            frame_0220.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10309
# Processed file [222/315]
#   Name:            frame_0221.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9827
# Processed file [223/315]
#   Name:            frame_0222.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10311
# Processed file [224/315]
#   Name:            frame_0223.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10804
# Processed file [225/315]
#   Name:            frame_0224.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10358
# Processed file [226/315]
#   Name:            frame_0225.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10533
# Processed file [227/315]
#   Name:            frame_0226.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9651
# Processed file [228/315]
#   Name:            frame_0227.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6556
# Processed file [229/315]
#   Name:            frame_0228.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6503
# Processed file [230/315]
#   Name:            frame_0229.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6456
# Processed file [231/315]
#   Name:            frame_0230.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6468
# Processed file [232/315]
#   Name:            frame_0231.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7125
# Processed file [233/315]
#   Name:            frame_0232.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6822
# Processed file [234/315]
#   Name:            frame_0233.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6688
# Processed file [235/315]
#   Name:            frame_0234.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6844
# Processed file [236/315]
#   Name:            frame_0235.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6608
# Processed file [237/315]
#   Name:            frame_0237.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5283
# Processed file [238/315]
#   Name:            frame_0236.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6184
# Processed file [239/315]
#   Name:            frame_0238.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        4931
# Processed file [240/315]
#   Name:            frame_0239.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        4948
# Processed file [241/315]
#   Name:            frame_0240.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        4691
# Processed file [242/315]
#   Name:            frame_0241.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        4988
# Processed file [243/315]
#   Name:            frame_0242.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5132
# Processed file [244/315]
#   Name:            frame_0243.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5318
# Processed file [245/315]
#   Name:            frame_0244.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5423
# Processed file [246/315]
#   Name:            frame_0245.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5472
# Processed file [247/315]
#   Name:            frame_0247.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5429
# Processed file [248/315]
#   Name:            frame_0246.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5717
# Processed file [249/315]
#   Name:            frame_0248.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5524
# Processed file [250/315]
#   Name:            frame_0249.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5804
# Processed file [251/315]
#   Name:            frame_0250.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5878
# Processed file [252/315]
#   Name:            frame_0251.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6022
# Processed file [253/315]
#   Name:            frame_0252.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5715
# Processed file [254/315]
#   Name:            frame_0253.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6025
# Processed file [255/315]
#   Name:            frame_0254.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6087
# Processed file [256/315]
#   Name:            frame_0255.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6388
# Processed file [257/315]
#   Name:            frame_0256.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6428
# Processed file [258/315]
#   Name:            frame_0257.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        5741
# Processed file [259/315]
#   Name:            frame_0258.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6049
# Processed file [260/315]
#   Name:            frame_0259.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6371
# Processed file [261/315]
#   Name:            frame_0260.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6510
# Processed file [262/315]
#   Name:            frame_0261.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6664
# Processed file [263/315]
#   Name:            frame_0262.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6398
# Processed file [264/315]
#   Name:            frame_0263.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6570
# Processed file [265/315]
#   Name:            frame_0264.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6891
# Processed file [266/315]
#   Name:            frame_0265.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6952
# Processed file [267/315]
#   Name:            frame_0266.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7085
# Processed file [268/315]
#   Name:            frame_0267.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6830
# Processed file [269/315]
#   Name:            frame_0268.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6866
# Processed file [270/315]
#   Name:            frame_0269.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7271
# Processed file [271/315]
#   Name:            frame_0270.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7315
# Processed file [272/315]
#   Name:            frame_0271.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7297
# Processed file [273/315]
#   Name:            frame_0272.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7062
# Processed file [274/315]
#   Name:            frame_0273.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7001
# Processed file [275/315]
#   Name:            frame_0274.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7101
# Processed file [276/315]
#   Name:            frame_0275.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7289
# Processed file [277/315]
#   Name:            frame_0276.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7361
# Processed file [278/315]
#   Name:            frame_0277.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7056
# Processed file [279/315]
#   Name:            frame_0278.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6846
# Processed file [280/315]
#   Name:            frame_0279.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7096
# Processed file [281/315]
#   Name:            frame_0280.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6990
# Processed file [282/315]
#   Name:            frame_0281.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6877
# Processed file [283/315]
#   Name:            frame_0282.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6600
# Processed file [284/315]
#   Name:            frame_0283.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6484
# Processed file [285/315]
#   Name:            frame_0284.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6684
# Processed file [286/315]
#   Name:            frame_0285.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6707
# Processed file [287/315]
#   Name:            frame_0286.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        6874
# Processed file [288/315]
#   Name:            frame_0287.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7001
# Processed file [289/315]
#   Name:            frame_0288.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7163
# Processed file [290/315]
#   Name:            frame_0289.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7504
# Processed file [291/315]
#   Name:            frame_0290.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        7860
# Processed file [292/315]
#   Name:            frame_0291.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8124
# Processed file [293/315]
#   Name:            frame_0292.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        8230
# Processed file [294/315]
#   Name:            frame_0293.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10040
# Processed file [295/315]
#   Name:            frame_0294.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10775
# Processed file [296/315]
#   Name:            frame_0295.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9877
# Processed file [297/315]
#   Name:            frame_0296.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10031
# Processed file [298/315]
#   Name:            frame_0297.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11660
# Processed file [299/315]
#   Name:            frame_0298.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11523
# Processed file [300/315]
#   Name:            frame_0299.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10941
# Processed file [301/315]
#   Name:            frame_0300.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11084
# Processed file [302/315]
#   Name:            frame_0302.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10819
# Processed file [303/315]
#   Name:            frame_0301.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10190
# Processed file [304/315]
#   Name:            frame_0303.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10791
# Processed file [305/315]
#   Name:            frame_0304.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10467
# Processed file [306/315]
#   Name:            frame_0305.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10563
# Processed file [307/315]
#   Name:            frame_0306.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11308
# Processed file [308/315]
#   Name:            frame_0307.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        11363
# Processed file [309/315]
#   Name:            frame_0308.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10624
# Processed file [310/315]
#   Name:            frame_0309.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10489
# Processed file [311/315]
#   Name:            frame_0310.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10107
# Processed file [312/315]
#   Name:            frame_0311.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9930
# Processed file [313/315]
#   Name:            frame_0312.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9919
# Processed file [314/315]
#   Name:            frame_0313.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        9616
# Processed file [315/315]
#   Name:            frame_0314.png
#   Dimensions:      1920 x 1080
#   Camera:          #1 - PINHOLE
#   Focal Length:    2304.00px
#   Features:        10211
# Elapsed time: 28.281 [minutes]

# %% [markdown]
# Match the features using the sequential matcher

# %%
# !colmap sequential_matcher \
    --database_path /content/drive/MyDrive/colmap_project/database.db \
    --SiftMatching.use_gpu 0
# Out:
# ==============================================================================
# Sequential feature matching
# ==============================================================================
#
# Matching image [1/315] in 13.834s
# Matching image [2/315] in 13.424s
# Matching image [3/315] in 12.394s
# Matching image [4/315] in 12.993s
# Matching image [5/315] in 13.715s
# Matching image [6/315] in 14.196s
# Matching image [7/315] in 14.830s
# Matching image [8/315] in 14.621s
# Matching image [9/315] in 15.094s
# Matching image [10/315] in 16.579s
# Matching image [11/315] in 23.574s
# Matching image [12/315] in 19.794s
# Matching image [13/315] in 18.416s
# Matching image [14/315] in 17.710s
# Matching image [15/315] in 17.982s
# Matching image [16/315] in 18.746s
# Matching image [17/315] in 17.888s
# Matching image [18/315] in 17.259s
# Matching image [19/315] in 13.207s
# Matching image [20/315] in 13.987s
# Matching image [21/315] in 15.185s
# Matching image [22/315] in 16.068s
# Matching image [23/315] in 17.857s
# Matching image [24/315] in 18.260s
# Matching image [25/315] in 20.923s
# Matching image [26/315] in 19.354s
# Matching image [27/315] in 18.929s
# Matching image [28/315] in 22.294s
# Matching image [29/315] in 20.475s
# Matching image [30/315] in 22.248s
# Matching image [31/315] in 20.419s
# Matching image [32/315] in 20.347s
# Matching image [33/315] in 20.489s
# Matching image [34/315] in 19.379s
# Matching image [35/315] in 24.727s
# Matching image [36/315] in 19.653s
# Matching image [37/315] in 20.694s
# Matching image [38/315] in 22.469s
# Matching image [39/315] in 21.041s
# Matching image [40/315] in 22.972s
# Matching image [41/315] in 20.802s
# Matching image [42/315] in 22.975s
# Matching image [43/315] in 20.873s
# Matching image [44/315] in 22.724s
# Matching image [45/315] in 25.522s
# Matching image [46/315] in 22.458s
# Matching image [47/315] in 21.685s
# Matching image [48/315] in 22.182s
# Matching image [49/315] in 20.292s
# Matching image [50/315] in 22.286s
# Matching image [51/315] in 20.380s
# Matching image [52/315] in 21.869s
# Matching image [53/315] in 20.188s
# Matching image [54/315] in 18.802s
# Matching image [55/315] in 24.815s
# Matching image [56/315] in 19.090s
# Matching image [57/315] in 21.532s
# Matching image [58/315] in 19.207s
# Matching image [59/315] in 18.857s
# Matching image [60/315] in 19.765s
# Matching image [61/315] in 19.847s
# Matching image [62/315] in 18.536s
# Matching image [63/315] in 17.837s
# Matching image [64/315] in 20.929s
# Matching image [65/315] in 18.389s
# Matching image [66/315] in 18.191s
# Matching image [67/315] in 19.569s
# Matching image [68/315] in 19.096s
# Matching image [69/315] in 18.295s
# Matching image [70/315] in 18.239s
# Matching image [71/315] in 19.368s
# Matching image [72/315] in 22.108s
# Matching image [73/315] in 19.329s
# Matching image [74/315] in 19.396s
# Matching image [75/315] in 18.359s
# Matching image [76/315] in 18.875s
# Matching image [77/315] in 20.432s
# Matching image [78/315] in 19.413s
# Matching image [79/315] in 19.007s
# Matching image [80/315] in 20.701s
# Matching image [81/315] in 18.812s
# Matching image [82/315] in 18.842s
# Matching image [83/315] in 18.306s
# Matching image [84/315] in 19.123s
# Matching image [85/315] in 18.383s
# Matching image [86/315] in 18.581s
# Matching image [87/315] in 24.276s
# Matching image [88/315] in 18.996s
# Matching image [89/315] in 18.820s
# Matching image [90/315] in 20.129s
# Matching image [91/315] in 16.213s
# Matching image [92/315] in 19.395s
# Matching image [93/315] in 22.873s
# Matching image [94/315] in 20.901s
# Matching image [95/315] in 22.139s
# Matching image [96/315] in 20.795s
# Matching image [97/315] in 22.555s
# Matching image [98/315] in 21.828s
# Matching image [99/315] in 26.304s
# Matching image [100/315] in 20.813s
# Matching image [101/315] in 22.803s
# Matching image [102/315] in 20.116s
# Matching image [103/315] in 22.934s
# Matching image [104/315] in 21.204s
# Matching image [105/315] in 21.801s
# Matching image [106/315] in 20.996s
# Matching image [107/315] in 21.463s
# Matching image [108/315] in 22.081s
# Matching image [109/315] in 26.464s
# Matching image [110/315] in 20.512s
# Matching image [111/315] in 22.145s
# Matching image [112/315] in 20.027s
# Matching image [113/315] in 20.829s
# Matching image [114/315] in 20.822s
# Matching image [115/315] in 18.238s
# Matching image [116/315] in 21.052s
# Matching image [117/315] in 20.610s
# Matching image [118/315] in 18.020s
# Matching image [119/315] in 21.718s
# Matching image [120/315] in 24.037s
# Matching image [121/315] in 19.217s
# Matching image [122/315] in 18.431s
# Matching image [123/315] in 20.876s
# Matching image [124/315] in 22.631s
# Matching image [125/315] in 20.073s
# Matching image [126/315] in 19.610s
# Matching image [127/315] in 21.001s
# Matching image [128/315] in 20.232s
# Matching image [129/315] in 21.420s
# Matching image [130/315] in 22.848s
# Matching image [131/315] in 20.771s
# Matching image [132/315] in 18.172s
# Matching image [133/315] in 19.192s
# Matching image [134/315] in 19.189s
# Matching image [135/315] in 18.354s
# Matching image [136/315] in 18.214s
# Matching image [137/315] in 17.520s
# Matching image [138/315] in 19.046s
# Matching image [139/315] in 18.958s
# Matching image [140/315] in 17.579s
# Matching image [141/315] in 18.481s
# Matching image [142/315] in 19.052s
# Matching image [143/315] in 18.502s
# Matching image [144/315] in 20.920s
# Matching image [145/315] in 18.144s
# Matching image [146/315] in 18.654s
# Matching image [147/315] in 18.407s
# Matching image [148/315] in 16.789s
# Matching image [149/315] in 17.203s
# Matching image [150/315] in 16.565s
# Matching image [151/315] in 17.137s
# Matching image [152/315] in 17.009s
# Matching image [153/315] in 15.881s
# Matching image [154/315] in 16.274s
# Matching image [155/315] in 15.628s
# Matching image [156/315] in 14.977s
# Matching image [157/315] in 15.147s
# Matching image [158/315] in 14.089s
# Matching image [159/315] in 14.094s
# Matching image [160/315] in 14.658s
# Matching image [161/315] in 14.711s
# Matching image [162/315] in 14.899s
# Matching image [163/315] in 17.136s
# Matching image [164/315] in 14.645s
# Matching image [165/315] in 14.236s
# Matching image [166/315] in 15.456s
# Matching image [167/315] in 15.324s
# Matching image [168/315] in 16.497s
# Matching image [169/315] in 16.991s
# Matching image [170/315] in 17.622s
# Matching image [171/315] in 17.129s
# Matching image [172/315] in 16.449s
# Matching image [173/315] in 16.191s
# Matching image [174/315] in 15.382s
# Matching image [175/315] in 15.416s
# Matching image [176/315] in 14.657s
# Matching image [177/315] in 14.064s
# Matching image [178/315] in 14.029s
# Matching image [179/315] in 12.667s
# Matching image [180/315] in 9.488s
# Matching image [181/315] in 10.734s
# Matching image [182/315] in 10.521s
# Matching image [183/315] in 7.791s
# Matching image [184/315] in 10.345s
# Matching image [185/315] in 10.560s
# Matching image [186/315] in 11.699s
# Matching image [187/315] in 12.880s
# Matching image [188/315] in 10.559s
# Matching image [189/315] in 10.913s
# Matching image [190/315] in 9.388s
# Matching image [191/315] in 12.087s
# Matching image [192/315] in 12.738s
# Matching image [193/315] in 13.126s
# Matching image [194/315] in 14.167s
# Matching image [195/315] in 15.169s
# Matching image [196/315] in 15.886s
# Matching image [197/315] in 16.597s
# Matching image [198/315] in 16.715s
# Matching image [199/315] in 16.900s
# Matching image [200/315] in 17.543s
# Matching image [201/315] in 21.968s
# Matching image [202/315] in 17.950s
# Matching image [203/315] in 17.709s
# Matching image [204/315] in 19.602s
# Matching image [205/315] in 17.824s
# Matching image [206/315] in 17.207s
# Matching image [207/315] in 16.843s
# Matching image [208/315] in 17.491s
# Matching image [209/315] in 18.422s
# Matching image [210/315] in 17.404s
# Matching image [211/315] in 17.295s
# Matching image [212/315] in 16.645s
# Matching image [213/315] in 20.498s
# Matching image [214/315] in 17.298s
# Matching image [215/315] in 16.421s
# Matching image [216/315] in 16.150s
# Matching image [217/315] in 16.492s
# Matching image [218/315] in 16.660s
# Matching image [219/315] in 16.067s
# Matching image [220/315] in 16.085s
# Matching image [221/315] in 15.078s
# Matching image [222/315] in 14.397s
# Matching image [223/315] in 14.670s
# Matching image [224/315] in 14.792s
# Matching image [225/315] in 14.040s
# Matching image [226/315] in 14.128s
# Matching image [227/315] in 16.345s
# Matching image [228/315] in 11.667s
# Matching image [229/315] in 11.078s
# Matching image [230/315] in 9.120s
# Matching image [231/315] in 11.103s
# Matching image [232/315] in 11.257s
# Matching image [233/315] in 9.553s
# Matching image [234/315] in 10.387s
# Matching image [235/315] in 11.261s
# Matching image [236/315] in 10.273s
# Matching image [237/315] in 8.776s
# Matching image [238/315] in 9.520s
# Matching image [239/315] in 7.271s
# Matching image [240/315] in 9.344s
# Matching image [241/315] in 8.062s
# Matching image [242/315] in 8.265s
# Matching image [243/315] in 9.661s
# Matching image [244/315] in 8.030s
# Matching image [245/315] in 10.137s
# Matching image [246/315] in 11.071s
# Matching image [247/315] in 11.755s
# Matching image [248/315] in 9.447s
# Matching image [249/315] in 10.265s
# Matching image [250/315] in 8.731s
# Matching image [251/315] in 10.463s
# Matching image [252/315] in 10.108s
# Matching image [253/315] in 7.867s
# Matching image [254/315] in 10.027s
# Matching image [255/315] in 9.888s
# Matching image [256/315] in 8.371s
# Matching image [257/315] in 10.381s
# Matching image [258/315] in 9.429s
# Matching image [259/315] in 8.964s
# Matching image [260/315] in 10.733s
# Matching image [261/315] in 10.102s
# Matching image [262/315] in 9.548s
# Matching image [263/315] in 12.721s
# Matching image [264/315] in 12.823s
# Matching image [265/315] in 11.270s
# Matching image [266/315] in 9.267s
# Matching image [267/315] in 11.460s
# Matching image [268/315] in 11.397s
# Matching image [269/315] in 10.752s
# Matching image [270/315] in 9.764s
# Matching image [271/315] in 11.597s
# Matching image [272/315] in 11.496s
# Matching image [273/315] in 9.832s
# Matching image [274/315] in 10.757s
# Matching image [275/315] in 14.364s
# Matching image [276/315] in 11.294s
# Matching image [277/315] in 11.352s
# Matching image [278/315] in 9.316s
# Matching image [279/315] in 11.157s
# Matching image [280/315] in 11.487s
# Matching image [281/315] in 10.845s
# Matching image [282/315] in 9.703s
# Matching image [283/315] in 11.281s
# Matching image [284/315] in 10.057s
# Matching image [285/315] in 8.260s
# Matching image [286/315] in 12.721s
# Matching image [287/315] in 12.495s
# Matching image [288/315] in 10.974s
# Matching image [289/315] in 9.327s
# Matching image [290/315] in 11.704s
# Matching image [291/315] in 12.371s
# Matching image [292/315] in 12.846s
# Matching image [293/315] in 12.829s
# Matching image [294/315] in 13.865s
# Matching image [295/315] in 14.667s
# Matching image [296/315] in 13.707s
# Matching image [297/315] in 13.682s
# Matching image [298/315] in 15.740s
# Matching image [299/315] in 15.523s
# Matching image [300/315] in 17.765s
# Matching image [301/315] in 14.136s
# Matching image [302/315] in 13.343s
# Matching image [303/315] in 13.176s
# Matching image [304/315] in 12.925s
# Matching image [305/315] in 12.569s
# Matching image [306/315] in 13.665s
# Matching image [307/315] in 12.468s
# Matching image [308/315] in 11.776s
# Matching image [309/315] in 7.973s
# Matching image [310/315] in 8.077s
# Matching image [311/315] in 4.699s
# Matching image [312/315] in 5.573s
# Matching image [313/315] in 2.380s
# Matching image [314/315] in 1.437s
# Matching image [315/315] in 0.000s
# Elapsed time: 84.189 [minutes]

# %% [markdown]
# Run sparse reconstruction (mapping)

# %%
# !colmap mapper \
    --database_path /content/drive/MyDrive/colmap_project/database.db \
    --image_path /content/drive/MyDrive/colmap_project/images \
    --output_path /content/drive/MyDrive/colmap_project/sparse \
    --Mapper.init_max_forward_motion 1 \
    --Mapper.init_min_tri_angle 0.5
# Out:
# Streaming output truncated to the last 5000 lines.
#     Residuals : 31864
#    Parameters : 3173
#    Iterations : 4
#          Time : 0.243076 [s]
#  Initial cost : 0.778228 [px]
#    Final cost : 0.771165 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 39
#   => Filtered observations: 7
#   => Changed observations: 0.002438
#
# ==============================================================================
# Registering image #234 (234)
# ==============================================================================
#
#   => Image sees 1238 / 4744 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2488
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0242102 [s]
#  Initial cost : 0.650271 [px]
#    Final cost : 0.648036 [px]
#   Termination : Convergence
#
#   => Continued observations: 1232
#   => Added observations: 1051
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29300
#    Parameters : 3272
#    Iterations : 18
#          Time : 0.976402 [s]
#  Initial cost : 0.629572 [px]
#    Final cost : 0.620135 [px]
#   Termination : Convergence
#
#   => Merged observations: 49
#   => Completed observations: 766
#   => Filtered observations: 141
#   => Changed observations: 0.057817
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29544
#    Parameters : 3206
#    Iterations : 4
#          Time : 0.329202 [s]
#  Initial cost : 0.777376 [px]
#    Final cost : 0.770384 [px]
#   Termination : Convergence
#
#   => Merged observations: 17
#   => Completed observations: 13
#   => Filtered observations: 1
#   => Changed observations: 0.001859
#
# ==============================================================================
# Registering image #235 (235)
# ==============================================================================
#
#   => Image sees 1414 / 5036 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2864
#    Parameters : 6
#    Iterations : 12
#          Time : 0.038554 [s]
#  Initial cost : 0.638762 [px]
#    Final cost : 0.63535 [px]
#   Termination : Convergence
#
#   => Continued observations: 1413
#   => Added observations: 1115
#
# Bundle adjustment report
# ------------------------
#     Residuals : 32344
#    Parameters : 3815
#    Iterations : 19
#          Time : 1.19316 [s]
#  Initial cost : 0.64537 [px]
#    Final cost : 0.619673 [px]
#   Termination : Convergence
#
#   => Merged observations: 107
#   => Completed observations: 495
#   => Filtered observations: 162
#   => Changed observations: 0.042217
#
# Bundle adjustment report
# ------------------------
#     Residuals : 32602
#    Parameters : 3740
#    Iterations : 4
#          Time : 0.340195 [s]
#  Initial cost : 0.774529 [px]
#    Final cost : 0.767106 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 25
#   => Filtered observations: 3
#   => Changed observations: 0.001535
#
# ==============================================================================
# Registering image #236 (236)
# ==============================================================================
#
#   => Image sees 1359 / 4614 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2740
#    Parameters : 6
#    Iterations : 11
#          Time : 0.031904 [s]
#  Initial cost : 0.659659 [px]
#    Final cost : 0.648101 [px]
#   Termination : Convergence
#
#   => Continued observations: 1350
#   => Added observations: 1500
#
# Bundle adjustment report
# ------------------------
#     Residuals : 31414
#    Parameters : 4139
#    Iterations : 19
#          Time : 1.34008 [s]
#  Initial cost : 0.66409 [px]
#    Final cost : 0.625797 [px]
#   Termination : Convergence
#
#   => Merged observations: 21
#   => Completed observations: 869
#   => Filtered observations: 199
#   => Changed observations: 0.063035
#
# Bundle adjustment report
# ------------------------
#     Residuals : 32004
#    Parameters : 4031
#    Iterations : 4
#          Time : 0.324312 [s]
#  Initial cost : 0.7671 [px]
#    Final cost : 0.759631 [px]
#   Termination : Convergence
#
#   => Merged observations: 20
#   => Completed observations: 31
#   => Filtered observations: 8
#   => Changed observations: 0.003396
#
# ==============================================================================
# Registering image #238 (237)
# ==============================================================================
#
#   => Image sees 1247 / 3984 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2512
#    Parameters : 6
#    Iterations : 12
#          Time : 0.052742 [s]
#  Initial cost : 0.723519 [px]
#    Final cost : 0.637325 [px]
#   Termination : Convergence
#
#   => Continued observations: 1241
#   => Added observations: 1316
#
# Bundle adjustment report
# ------------------------
#     Residuals : 30412
#    Parameters : 3509
#    Iterations : 26
#          Time : 1.53406 [s]
#  Initial cost : 0.620247 [px]
#    Final cost : 0.607992 [px]
#   Termination : No convergence
#
#   => Merged observations: 25
#   => Completed observations: 1005
#   => Filtered observations: 156
#   => Changed observations: 0.069324
#
# Bundle adjustment report
# ------------------------
#     Residuals : 30864
#    Parameters : 3452
#    Iterations : 3
#          Time : 0.209951 [s]
#  Initial cost : 0.762164 [px]
#    Final cost : 0.753543 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 56
#   => Filtered observations: 2
#   => Changed observations: 0.003343
#
# ==============================================================================
# Registering image #237 (238)
# ==============================================================================
#
#   => Image sees 1251 / 3513 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2518
#    Parameters : 6
#    Iterations : 11
#          Time : 0.026314 [s]
#  Initial cost : 0.743559 [px]
#    Final cost : 0.740985 [px]
#   Termination : Convergence
#
#   => Continued observations: 1244
#   => Added observations: 972
#
# Bundle adjustment report
# ------------------------
#     Residuals : 31116
#    Parameters : 3254
#    Iterations : 22
#          Time : 1.13501 [s]
#  Initial cost : 0.70328 [px]
#    Final cost : 0.652546 [px]
#   Termination : Convergence
#
#   => Merged observations: 49
#   => Completed observations: 867
#   => Filtered observations: 330
#   => Changed observations: 0.070836
#
# Bundle adjustment report
# ------------------------
#     Residuals : 31560
#    Parameters : 3218
#    Iterations : 4
#          Time : 0.317423 [s]
#  Initial cost : 0.786508 [px]
#    Final cost : 0.776623 [px]
#   Termination : Convergence
#
#   => Merged observations: 30
#   => Completed observations: 28
#   => Filtered observations: 5
#   => Changed observations: 0.003536
#
# ==============================================================================
# Registering image #239 (239)
# ==============================================================================
#
#   => Image sees 945 / 2933 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1856
#    Parameters : 6
#    Iterations : 15
#          Time : 0.0319312 [s]
#  Initial cost : 0.85382 [px]
#    Final cost : 0.839413 [px]
#   Termination : Convergence
#
#   => Continued observations: 920
#   => Added observations: 637
#
# Bundle adjustment report
# ------------------------
#     Residuals : 28520
#    Parameters : 2261
#    Iterations : 26
#          Time : 1.34522 [s]
#  Initial cost : 0.698509 [px]
#    Final cost : 0.686942 [px]
#   Termination : No convergence
#
#   => Merged observations: 0
#   => Completed observations: 715
#   => Filtered observations: 543
#   => Changed observations: 0.077654
#
# Bundle adjustment report
# ------------------------
#     Residuals : 28256
#    Parameters : 2162
#    Iterations : 5
#          Time : 0.380266 [s]
#  Initial cost : 0.816292 [px]
#    Final cost : 0.803834 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 99
#   => Filtered observations: 16
#   => Changed observations: 0.007250
#
# ==============================================================================
# Registering image #240 (240)
# ==============================================================================
#
#   => Image sees 951 / 3055 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1924
#    Parameters : 6
#    Iterations : 11
#          Time : 0.024919 [s]
#  Initial cost : 0.723726 [px]
#    Final cost : 0.692849 [px]
#   Termination : Convergence
#
#   => Continued observations: 947
#   => Added observations: 673
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29168
#    Parameters : 2573
#    Iterations : 26
#          Time : 1.53353 [s]
#  Initial cost : 0.67785 [px]
#    Final cost : 0.651438 [px]
#   Termination : No convergence
#
#   => Merged observations: 26
#   => Completed observations: 973
#   => Filtered observations: 231
#   => Changed observations: 0.075151
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29098
#    Parameters : 2465
#    Iterations : 4
#          Time : 0.221125 [s]
#  Initial cost : 0.819467 [px]
#    Final cost : 0.808822 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 64
#   => Filtered observations: 1
#   => Changed observations: 0.003974
#
# ==============================================================================
# Registering image #241 (241)
# ==============================================================================
#
#   => Image sees 1005 / 3101 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2032
#    Parameters : 6
#    Iterations : 16
#          Time : 0.038877 [s]
#  Initial cost : 0.741131 [px]
#    Final cost : 0.715964 [px]
#   Termination : Convergence
#
#   => Continued observations: 997
#   => Added observations: 757
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29852
#    Parameters : 2852
#    Iterations : 26
#          Time : 1.86553 [s]
#  Initial cost : 0.703655 [px]
#    Final cost : 0.668546 [px]
#   Termination : No convergence
#
#   => Merged observations: 34
#   => Completed observations: 703
#   => Filtered observations: 294
#   => Changed observations: 0.062561
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29780
#    Parameters : 2759
#    Iterations : 4
#          Time : 0.323953 [s]
#  Initial cost : 0.828434 [px]
#    Final cost : 0.819417 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 62
#   => Filtered observations: 9
#   => Changed observations: 0.004316
#
# ==============================================================================
# Registering image #242 (242)
# ==============================================================================
#
#   => Image sees 958 / 3124 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1952
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0376332 [s]
#  Initial cost : 0.665913 [px]
#    Final cost : 0.664121 [px]
#   Termination : Convergence
#
#   => Continued observations: 956
#   => Added observations: 873
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29166
#    Parameters : 2921
#    Iterations : 26
#          Time : 1.46445 [s]
#  Initial cost : 0.688944 [px]
#    Final cost : 0.653508 [px]
#   Termination : No convergence
#
#   => Merged observations: 155
#   => Completed observations: 927
#   => Filtered observations: 219
#   => Changed observations: 0.081752
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29470
#    Parameters : 2798
#    Iterations : 4
#          Time : 0.231563 [s]
#  Initial cost : 0.825125 [px]
#    Final cost : 0.816007 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 44
#   => Filtered observations: 8
#   => Changed observations: 0.003233
#
# ==============================================================================
# Registering image #243 (243)
# ==============================================================================
#
#   => Image sees 925 / 3462 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1896
#    Parameters : 6
#    Iterations : 12
#          Time : 0.049171 [s]
#  Initial cost : 0.700817 [px]
#    Final cost : 0.696077 [px]
#   Termination : Convergence
#
#   => Continued observations: 922
#   => Added observations: 1104
#
# Bundle adjustment report
# ------------------------
#     Residuals : 28374
#    Parameters : 2669
#    Iterations : 21
#          Time : 1.20516 [s]
#  Initial cost : 0.68174 [px]
#    Final cost : 0.669239 [px]
#   Termination : Convergence
#
#   => Merged observations: 54
#   => Completed observations: 1039
#   => Filtered observations: 225
#   => Changed observations: 0.085757
#
# Bundle adjustment report
# ------------------------
#     Residuals : 30772
#    Parameters : 2891
#    Iterations : 4
#          Time : 0.238129 [s]
#  Initial cost : 0.819953 [px]
#    Final cost : 0.810425 [px]
#   Termination : Convergence
#
#   => Merged observations: 8
#   => Completed observations: 52
#   => Filtered observations: 4
#   => Changed observations: 0.003787
#
# ==============================================================================
# Registering image #244 (244)
# ==============================================================================
#
#   => Image sees 1113 / 3760 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2274
#    Parameters : 6
#    Iterations : 10
#          Time : 0.022212 [s]
#  Initial cost : 0.666507 [px]
#    Final cost : 0.633373 [px]
#   Termination : Convergence
#
#   => Continued observations: 1106
#   => Added observations: 825
#
# Bundle adjustment report
# ------------------------
#     Residuals : 30620
#    Parameters : 2828
#    Iterations : 18
#          Time : 1.19617 [s]
#  Initial cost : 0.676562 [px]
#    Final cost : 0.658378 [px]
#   Termination : Convergence
#
#   => Merged observations: 51
#   => Completed observations: 688
#   => Filtered observations: 206
#   => Changed observations: 0.057048
#
# Bundle adjustment report
# ------------------------
#     Residuals : 32250
#    Parameters : 2795
#    Iterations : 4
#          Time : 0.349886 [s]
#  Initial cost : 0.824222 [px]
#    Final cost : 0.818008 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 43
#   => Filtered observations: 3
#   => Changed observations: 0.002640
#
# ==============================================================================
# Registering image #245 (245)
# ==============================================================================
#
#   => Image sees 1085 / 3753 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2220
#    Parameters : 6
#    Iterations : 12
#          Time : 0.0278051 [s]
#  Initial cost : 0.633332 [px]
#    Final cost : 0.618458 [px]
#   Termination : Convergence
#
#   => Continued observations: 1081
#   => Added observations: 839
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29586
#    Parameters : 2789
#    Iterations : 19
#          Time : 1.0327 [s]
#  Initial cost : 0.700294 [px]
#    Final cost : 0.670367 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 636
#   => Filtered observations: 182
#   => Changed observations: 0.047946
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29784
#    Parameters : 2720
#    Iterations : 4
#          Time : 0.22027 [s]
#  Initial cost : 0.85236 [px]
#    Final cost : 0.845005 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 28
#   => Filtered observations: 4
#   => Changed observations: 0.001863
#
# ==============================================================================
# Registering image #246 (246)
# ==============================================================================
#
#   => Image sees 1097 / 3832 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2242
#    Parameters : 6
#    Iterations : 15
#          Time : 0.033999 [s]
#  Initial cost : 0.715502 [px]
#    Final cost : 0.677369 [px]
#   Termination : Convergence
#
#   => Continued observations: 1091
#   => Added observations: 878
#
# Bundle adjustment report
# ------------------------
#     Residuals : 30090
#    Parameters : 2783
#    Iterations : 16
#          Time : 0.92972 [s]
#  Initial cost : 0.679259 [px]
#    Final cost : 0.651472 [px]
#   Termination : Convergence
#
#   => Merged observations: 14
#   => Completed observations: 620
#   => Filtered observations: 222
#   => Changed observations: 0.053062
#
# Bundle adjustment report
# ------------------------
#     Residuals : 30214
#    Parameters : 2792
#    Iterations : 4
#          Time : 0.302507 [s]
#  Initial cost : 0.852748 [px]
#    Final cost : 0.846022 [px]
#   Termination : Convergence
#
#   => Merged observations: 84
#   => Completed observations: 50
#   => Filtered observations: 1
#   => Changed observations: 0.007723
#
# ==============================================================================
# Registering image #248 (247)
# ==============================================================================
#
#   => Image sees 1191 / 3921 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2422
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0388482 [s]
#  Initial cost : 0.609454 [px]
#    Final cost : 0.608217 [px]
#   Termination : Convergence
#
#   => Continued observations: 1186
#   => Added observations: 657
#
# Bundle adjustment report
# ------------------------
#     Residuals : 31056
#    Parameters : 2783
#    Iterations : 23
#          Time : 1.49379 [s]
#  Initial cost : 0.678958 [px]
#    Final cost : 0.647006 [px]
#   Termination : Convergence
#
#   => Merged observations: 38
#   => Completed observations: 406
#   => Filtered observations: 185
#   => Changed observations: 0.037717
#
# Bundle adjustment report
# ------------------------
#     Residuals : 31078
#    Parameters : 2705
#    Iterations : 3
#          Time : 0.278172 [s]
#  Initial cost : 0.81629 [px]
#    Final cost : 0.811006 [px]
#   Termination : Convergence
#
#   => Merged observations: 10
#   => Completed observations: 49
#   => Filtered observations: 2
#   => Changed observations: 0.003655
#
# ==============================================================================
# Registering image #247 (248)
# ==============================================================================
#
#   => Image sees 1070 / 3753 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2198
#    Parameters : 6
#    Iterations : 8
#          Time : 0.024672 [s]
#  Initial cost : 0.639614 [px]
#    Final cost : 0.639053 [px]
#   Termination : Convergence
#
#   => Continued observations: 1067
#   => Added observations: 682
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27746
#    Parameters : 2504
#    Iterations : 15
#          Time : 0.872286 [s]
#  Initial cost : 0.698895 [px]
#    Final cost : 0.670583 [px]
#   Termination : Convergence
#
#   => Merged observations: 27
#   => Completed observations: 472
#   => Filtered observations: 169
#   => Changed observations: 0.040500
#
# Bundle adjustment report
# ------------------------
#     Residuals : 23394
#    Parameters : 2375
#    Iterations : 4
#          Time : 0.206199 [s]
#  Initial cost : 0.853469 [px]
#    Final cost : 0.846921 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 31
#   => Filtered observations: 6
#   => Changed observations: 0.002692
#
# ==============================================================================
# Registering image #249 (249)
# ==============================================================================
#
#   => Image sees 1088 / 3789 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2216
#    Parameters : 6
#    Iterations : 11
#          Time : 0.0292978 [s]
#  Initial cost : 0.707972 [px]
#    Final cost : 0.621347 [px]
#   Termination : Convergence
#
#   => Continued observations: 1080
#   => Added observations: 845
#
# Bundle adjustment report
# ------------------------
#     Residuals : 24216
#    Parameters : 2450
#    Iterations : 23
#          Time : 1.07695 [s]
#  Initial cost : 0.673041 [px]
#    Final cost : 0.666161 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 592
#   => Filtered observations: 160
#   => Changed observations: 0.052954
#
# Bundle adjustment report
# ------------------------
#     Residuals : 24194
#    Parameters : 2381
#    Iterations : 4
#          Time : 0.244589 [s]
#  Initial cost : 0.845195 [px]
#    Final cost : 0.838371 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 30
#   => Filtered observations: 2
#   => Changed observations: 0.002253
#
# ==============================================================================
# Registering image #250 (250)
# ==============================================================================
#
#   => Image sees 1203 / 4026 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2448
#    Parameters : 6
#    Iterations : 13
#          Time : 0.0462222 [s]
#  Initial cost : 0.646263 [px]
#    Final cost : 0.613395 [px]
#   Termination : Convergence
#
#   => Continued observations: 1200
#   => Added observations: 562
#
# Bundle adjustment report
# ------------------------
#     Residuals : 24074
#    Parameters : 2618
#    Iterations : 25
#          Time : 1.30908 [s]
#  Initial cost : 0.675147 [px]
#    Final cost : 0.657177 [px]
#   Termination : Convergence
#
#   => Merged observations: 10
#   => Completed observations: 383
#   => Filtered observations: 170
#   => Changed observations: 0.040747
#
# Bundle adjustment report
# ------------------------
#     Residuals : 23946
#    Parameters : 2561
#    Iterations : 3
#          Time : 0.142996 [s]
#  Initial cost : 0.82841 [px]
#    Final cost : 0.823947 [px]
#   Termination : Convergence
#
#   => Merged observations: 13
#   => Completed observations: 41
#   => Filtered observations: 1
#   => Changed observations: 0.003998
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 137
#   => Merged observations: 96
#   => Retriangulated observations: 1541
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.303435e+06    0.00e+00    3.11e+06   0.00e+00   0.00e+00  1.00e+04        0    1.79e+00    9.63e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 8.9631e+08
#     Nonzeros in L:       1.0229e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       3.7
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 8.9631e+08
#         nnz(L):     1.0229e+06
#   OK
#    1  9.563478e+05    3.47e+05    8.67e+05   3.74e+01   8.82e-01  1.81e+04        1    1.06e+01    2.02e+01
#    2  9.128909e+05    4.35e+04    2.21e+05   4.50e+01   9.34e-01  5.21e+04        1    6.53e+00    2.67e+01
#    3  9.082276e+05    4.66e+03    5.19e+04   4.37e+01   9.79e-01  1.56e+05        1    7.29e+00    3.40e+01
#    4  9.078055e+05    4.22e+02    2.16e+04   2.52e+01   1.03e+00  4.69e+05        1    6.07e+00    4.01e+01
#    5  9.077610e+05    4.45e+01    1.37e+04   1.38e+01   9.99e-01  1.41e+06        1    7.76e+00    4.79e+01
#    6  9.077521e+05    8.96e+00    6.76e+03   6.32e+01   7.60e-01  1.64e+06        1    5.68e+00    5.35e+01
#    7  9.077492e+05    2.90e+00    3.68e+03   8.30e+02   6.72e-01  1.71e+06        1    8.21e+00    6.18e+01
#    8  9.077489e+05    2.30e-01    1.96e+03   9.48e+02   7.10e-01  1.84e+06        1    5.92e+00    6.77e+01
#    9  9.077489e+05    3.69e-02    2.11e+03   2.45e+02   3.74e-01  1.81e+06        1    7.88e+00    7.56e+01
#   10  9.077489e+05    6.57e-03    1.68e+03   1.89e+02   1.07e-01  1.22e+06        1    5.73e+00    8.13e+01
#   11  9.077489e+05    3.73e-03    1.79e+03   1.07e+02   7.30e-02  7.53e+05        1    8.11e+00    8.94e+01
#   12  9.077489e+05    4.95e-03    1.43e+03   6.04e+01   1.11e-01  5.13e+05        1    5.80e+00    9.52e+01
#   13  9.077489e+05    4.23e-03    1.42e+03   3.91e+01   1.21e-01  3.57e+05        1    7.90e+00    1.03e+02
#   14  9.077489e+05    4.53e-03    1.09e+03   2.64e+01   1.69e-01  2.77e+05        1    5.94e+00    1.09e+02
#   15  9.077489e+05    3.41e-03    9.57e+02   2.00e+01   1.89e-01  2.23e+05        1    7.96e+00    1.17e+02
#   16  9.077489e+05    2.61e-03    6.92e+02   1.59e+01   2.28e-01  1.92e+05        1    5.88e+00    1.23e+02
#   17  9.077489e+05    1.59e-03    5.39e+02   1.35e+01   2.46e-01  1.70e+05        1    8.27e+00    1.31e+02
#   18  9.077489e+05    9.40e-04    3.70e+02   1.18e+01   2.74e-01  1.55e+05        1    6.19e+00    1.37e+02
#   19  9.077489e+05    4.90e-04    2.62e+02   1.07e+01   2.93e-01  1.45e+05        1    7.83e+00    1.45e+02
#   20  9.077489e+05    2.51e-04    1.72e+02   9.92e+00   3.19e-01  1.38e+05        1    5.74e+00    1.51e+02
#   21  9.077489e+05    1.26e-04    1.14e+02   9.40e+00   3.53e-01  1.35e+05        1    7.87e+00    1.59e+02
#   22  9.077489e+05    6.82e-05    7.34e+01   9.10e+00   4.12e-01  1.34e+05        1    5.93e+00    1.65e+02
#   23  9.077489e+05    4.24e-05    4.75e+01   8.98e+00   5.13e-01  1.34e+05        1    9.00e+00    1.74e+02
#   24  9.077489e+05    3.16e-05    3.04e+01   8.92e+00   6.55e-01  1.38e+05        1    6.10e+00    1.80e+02
#   25  9.077489e+05    2.76e-05    1.97e+01   9.13e+00   7.97e-01  1.75e+05        1    7.62e+00    1.87e+02
#   26  9.077489e+05    3.18e-05    1.33e+01   1.15e+01   9.07e-01  3.82e+05        1    5.93e+00    1.93e+02
#   27  9.077489e+05    6.57e-05    1.02e+01   2.48e+01   9.64e-01  1.15e+06        1    6.70e+00    2.00e+02
#   28  9.077489e+05    1.86e-04    9.04e+00   7.31e+01   9.66e-01  3.44e+06        1    6.70e+00    2.07e+02
#   29  9.077489e+05    4.78e-04    8.50e+00   2.08e+02   9.28e-01  9.20e+06        1    6.05e+00    2.13e+02
#   30  9.077489e+05    8.86e-04    8.14e+00   4.81e+02   8.60e-01  1.47e+07        1    8.37e+00    2.21e+02
#   31  9.077489e+05    7.73e-04    7.84e+00   5.68e+02   8.58e-01  2.31e+07        1    6.01e+00    2.27e+02
#   32  9.077488e+05    6.63e-04    7.56e+00   6.61e+02   8.58e-01  3.65e+07        1    7.70e+00    2.35e+02
#   33  9.077488e+05    5.69e-04    7.30e+00   7.69e+02   8.58e-01  5.77e+07        1    5.76e+00    2.41e+02
#   34  9.077488e+05    4.89e-04    7.05e+00   8.95e+02   8.58e-01  9.10e+07        1    8.01e+00    2.49e+02
#   35  9.077488e+05    4.20e-04    6.82e+00   1.04e+03   8.58e-01  1.44e+08        1    5.92e+00    2.55e+02
#   36  9.077488e+05    3.61e-04    6.59e+00   1.21e+03   8.58e-01  2.27e+08        1    7.99e+00    2.63e+02
#   37  9.077488e+05    3.10e-04    6.38e+00   1.41e+03   8.58e-01  3.57e+08        1    5.75e+00    2.68e+02
#   38  9.077488e+05    2.67e-04    6.17e+00   1.64e+03   8.58e-01  5.64e+08        1    7.75e+00    2.76e+02
#   39  9.077488e+05    2.30e-04    5.97e+00   1.91e+03   8.58e-01  8.92e+08        1    5.83e+00    2.82e+02
#   40  9.077488e+05    1.99e-04    5.77e+00   2.23e+03   8.59e-01  1.41e+09        1    7.79e+00    2.90e+02
#   41  9.077488e+05    1.74e-04    5.58e+00   2.61e+03   8.59e-01  2.25e+09        1    5.72e+00    2.95e+02
#   42  9.077488e+05    1.53e-04    5.40e+00   3.05e+03   8.61e-01  3.60e+09        1    7.79e+00    3.03e+02
#   43  9.077488e+05    1.36e-04    5.22e+00   3.60e+03   8.63e-01  5.82e+09        1    5.74e+00    3.09e+02
#   44  9.077488e+05    1.22e-04    5.06e+00   4.27e+03   8.65e-01  9.52e+09        1    7.41e+00    3.16e+02
#   45  9.077488e+05    1.11e-04    4.87e+00   5.10e+03   8.67e-01  1.57e+10        1    5.86e+00    3.22e+02
#   46  9.077488e+05    9.83e-05    4.75e+00   6.12e+03   8.67e-01  2.60e+10        1    6.63e+00    3.29e+02
#   47  9.077488e+05    8.33e-05    4.54e+00   7.29e+03   8.64e-01  4.24e+10        1    7.29e+00    3.36e+02
#   48  9.077488e+05    6.66e-05    4.45e+00   8.54e+03   8.58e-01  6.71e+10        1    6.34e+00    3.42e+02
#   49  9.077488e+05    5.16e-05    4.28e+00   9.72e+03   8.54e-01  1.04e+11        1    7.61e+00    3.50e+02
#   50  9.077488e+05    4.11e-05    4.15e+00   1.10e+04   8.54e-01  1.61e+11        1    5.70e+00    3.56e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 1723852
#    Parameters : 265318
#    Iterations : 51
#          Time : 355.898 [s]
#  Initial cost : 0.86955 [px]
#    Final cost : 0.725659 [px]
#   Termination : No convergence
#
#   => Completed observations: 1293
#   => Merged observations: 1921
#   => Filtered observations: 2136
#   => Changed observations: 0.006207
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  7.269065e+05    0.00e+00    1.14e+06   0.00e+00   0.00e+00  1.00e+04        0    2.81e+00    1.39e+01
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 8.8609e+08
#     Nonzeros in L:       1.0168e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       3.6
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 8.8609e+08
#         nnz(L):     1.0168e+06
#   OK
#    1  7.171175e+05    9.79e+03    4.24e+04   2.19e+00   1.00e+00  3.00e+04        1    8.56e+00    2.24e+01
#    2  7.170502e+05    6.73e+01    2.29e+04   9.02e-01   9.63e-01  9.00e+04        1    7.96e+00    3.04e+01
#    3  7.170363e+05    1.40e+01    1.79e+04   1.78e+00   9.28e-01  2.40e+05        1    5.88e+00    3.63e+01
#    4  7.170288e+05    7.43e+00    2.54e+03   3.37e+00   9.63e-01  7.20e+05        1    8.06e+00    4.43e+01
#    5  7.170229e+05    5.94e+00    6.40e+03   5.10e+00   7.94e-01  9.05e+05        1    5.77e+00    5.01e+01
#    6  7.170195e+05    3.43e+00    2.16e+03   2.91e+00   9.57e-01  2.71e+06        1    8.06e+00    5.82e+01
#    7  7.170188e+05    6.47e-01    9.32e+02   1.90e+00   9.62e-01  8.14e+06        1    5.89e+00    6.40e+01
#    8  7.170188e+05    5.78e-02    6.39e+01   4.92e-01   1.01e+00  2.44e+07        1    8.36e+00    7.24e+01
#    9  7.170188e+05    4.93e-04    2.26e+01   5.22e-02   1.03e+00  7.33e+07        1    5.76e+00    7.82e+01
#   10  7.170188e+05    4.68e-06    1.17e+01   6.61e-03   7.72e-01  8.74e+07        1    8.29e+00    8.64e+01
#   11  7.170188e+05    1.65e-06    6.38e+00   6.64e-03   7.88e-01  1.08e+08        1    5.94e+00    9.24e+01
#   12  7.170188e+05    1.62e-06    3.48e+00   8.19e-03   9.13e-01  2.49e+08        1    7.83e+00    1.00e+02
#   13  7.170188e+05    3.54e-06    1.93e+00   1.88e-02   9.90e-01  7.47e+08        1    5.86e+00    1.06e+02
#   14  7.170188e+05    1.04e-05    2.00e+00   5.59e-02   9.98e-01  2.24e+09        1    7.82e+00    1.14e+02
#   15  7.170188e+05    2.98e-05    9.18e-01   1.64e-01   1.00e+00  6.72e+09        1    5.87e+00    1.20e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 1721762
#    Parameters : 264256
#    Iterations : 16
#          Time : 119.908 [s]
#  Initial cost : 0.64976 [px]
#    Final cost : 0.645325 [px]
#   Termination : Convergence
#
#   => Completed observations: 494
#   => Merged observations: 511
#   => Filtered observations: 205
#   => Changed observations: 0.001406
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  7.180663e+05    0.00e+00    2.22e+05   0.00e+00   0.00e+00  1.00e+04        0    1.53e+00    9.41e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 8.8371e+08
#     Nonzeros in L:       1.017e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       3.6
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 8.8371e+08
#         nnz(L):     1.017e+06
#   OK
#    1  7.172049e+05    8.61e+02    9.76e+03   3.71e-01   9.99e-01  3.00e+04        1    1.04e+01    1.99e+01
#    2  7.171991e+05    5.73e+00    6.10e+03   8.39e-02   9.48e-01  9.00e+04        1    5.74e+00    2.56e+01
#    3  7.171983e+05    8.67e-01    3.90e+03   6.99e-02   8.98e-01  1.81e+05        1    7.78e+00    3.34e+01
#    4  7.171982e+05    2.77e-02    1.80e+02   6.51e-02   1.02e+00  5.43e+05        1    5.73e+00    3.91e+01
#    5  7.171982e+05    3.47e-03    6.60e+01   9.02e-02   9.97e-01  1.63e+06        1    7.77e+00    4.69e+01
#    6  7.171982e+05    1.15e-03    2.24e+01   8.07e-02   1.00e+00  4.88e+06        1    5.77e+00    5.26e+01
#    7  7.171982e+05    1.27e-04    9.27e+00   3.21e-02   1.01e+00  1.47e+07        1    8.09e+00    6.07e+01
#    8  7.171982e+05    3.27e-06    4.70e+00   5.11e-03   9.73e-01  4.40e+07        1    5.90e+00    6.66e+01
#    9  7.171982e+05    4.01e-07    2.18e+00   2.43e-03   9.04e-01  9.34e+07        1    7.76e+00    7.44e+01
#   10  7.171982e+05    6.97e-07    1.53e+00   5.12e-03   9.77e-01  2.80e+08        1    5.73e+00    8.01e+01
#   11  7.171982e+05    2.06e-06    1.69e+00   1.53e-02   9.96e-01  8.40e+08        1    7.73e+00    8.79e+01
#   12  7.171982e+05    6.11e-06    1.70e+00   4.55e-02   1.00e+00  2.52e+09        1    5.70e+00    9.36e+01
#   13  7.171982e+05    1.75e-05    8.88e-01   1.33e-01   1.00e+00  7.56e+09        1    7.25e+00    1.01e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 1722330
#    Parameters : 264211
#    Iterations : 14
#          Time : 101.051 [s]
#  Initial cost : 0.64569 [px]
#    Final cost : 0.6453 [px]
#   Termination : Convergence
#
#   => Completed observations: 160
#   => Merged observations: 47
#   => Filtered observations: 91
#   => Changed observations: 0.000346
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #251 (251)
# ==============================================================================
#
#   => Image sees 1145 / 3939 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2308
#    Parameters : 6
#    Iterations : 11
#          Time : 0.0248861 [s]
#  Initial cost : 0.613998 [px]
#    Final cost : 0.574603 [px]
#   Termination : Convergence
#
#   => Continued observations: 1138
#   => Added observations: 1123
#
# Bundle adjustment report
# ------------------------
#     Residuals : 33574
#    Parameters : 4568
#    Iterations : 26
#          Time : 1.39011 [s]
#  Initial cost : 0.60802 [px]
#    Final cost : 0.586839 [px]
#   Termination : No convergence
#
#   => Merged observations: 25
#   => Completed observations: 511
#   => Filtered observations: 158
#   => Changed observations: 0.038810
#
# Bundle adjustment report
# ------------------------
#     Residuals : 33724
#    Parameters : 4481
#    Iterations : 4
#          Time : 0.318622 [s]
#  Initial cost : 0.724158 [px]
#    Final cost : 0.716588 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 44
#   => Filtered observations: 4
#   => Changed observations: 0.002671
#
# ==============================================================================
# Registering image #252 (252)
# ==============================================================================
#
#   => Image sees 1129 / 3614 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2266
#    Parameters : 6
#    Iterations : 21
#          Time : 0.0534708 [s]
#  Initial cost : 0.682864 [px]
#    Final cost : 0.675873 [px]
#   Termination : Convergence
#
#   => Continued observations: 1121
#   => Added observations: 1050
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25548
#    Parameters : 2984
#    Iterations : 26
#          Time : 1.41956 [s]
#  Initial cost : 0.615378 [px]
#    Final cost : 0.596041 [px]
#   Termination : No convergence
#
#   => Merged observations: 0
#   => Completed observations: 563
#   => Filtered observations: 154
#   => Changed observations: 0.050415
#
# Bundle adjustment report
# ------------------------
#     Residuals : 26016
#    Parameters : 2735
#    Iterations : 4
#          Time : 0.19023 [s]
#  Initial cost : 0.727608 [px]
#    Final cost : 0.719018 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 16
#   => Filtered observations: 5
#   => Changed observations: 0.001486
#
# ==============================================================================
# Registering image #253 (253)
# ==============================================================================
#
#   => Image sees 1098 / 3462 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2180
#    Parameters : 6
#    Iterations : 16
#          Time : 0.0330291 [s]
#  Initial cost : 0.802886 [px]
#    Final cost : 0.788814 [px]
#   Termination : Convergence
#
#   => Continued observations: 1079
#   => Added observations: 771
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25728
#    Parameters : 2732
#    Iterations : 26
#          Time : 1.25744 [s]
#  Initial cost : 0.680475 [px]
#    Final cost : 0.654413 [px]
#   Termination : No convergence
#
#   => Merged observations: 0
#   => Completed observations: 454
#   => Filtered observations: 476
#   => Changed observations: 0.064583
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25356
#    Parameters : 2432
#    Iterations : 4
#          Time : 0.267171 [s]
#  Initial cost : 0.765322 [px]
#    Final cost : 0.750543 [px]
#   Termination : Convergence
#
#   => Merged observations: 10
#   => Completed observations: 94
#   => Filtered observations: 18
#   => Changed observations: 0.008734
#
# ==============================================================================
# Registering image #254 (254)
# ==============================================================================
#
#   => Image sees 1109 / 3545 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2218
#    Parameters : 6
#    Iterations : 13
#          Time : 0.0471439 [s]
#  Initial cost : 0.70594 [px]
#    Final cost : 0.656901 [px]
#   Termination : Convergence
#
#   => Continued observations: 1101
#   => Added observations: 789
#
# Bundle adjustment report
# ------------------------
#     Residuals : 26038
#    Parameters : 2732
#    Iterations : 26
#          Time : 1.58514 [s]
#  Initial cost : 0.626174 [px]
#    Final cost : 0.611254 [px]
#   Termination : No convergence
#
#   => Merged observations: 38
#   => Completed observations: 390
#   => Filtered observations: 204
#   => Changed observations: 0.043116
#
# Bundle adjustment report
# ------------------------
#     Residuals : 26166
#    Parameters : 2684
#    Iterations : 4
#          Time : 0.289482 [s]
#  Initial cost : 0.753512 [px]
#    Final cost : 0.742896 [px]
#   Termination : Convergence
#
#   => Merged observations: 24
#   => Completed observations: 49
#   => Filtered observations: 4
#   => Changed observations: 0.005230
#
# ==============================================================================
# Registering image #255 (255)
# ==============================================================================
#
#   => Image sees 1094 / 3718 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2194
#    Parameters : 6
#    Iterations : 15
#          Time : 0.0320339 [s]
#  Initial cost : 0.706179 [px]
#    Final cost : 0.694985 [px]
#   Termination : Convergence
#
#   => Continued observations: 1087
#   => Added observations: 1049
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25874
#    Parameters : 2786
#    Iterations : 26
#          Time : 1.09796 [s]
#  Initial cost : 0.640668 [px]
#    Final cost : 0.625732 [px]
#   Termination : No convergence
#
#   => Merged observations: 62
#   => Completed observations: 519
#   => Filtered observations: 270
#   => Changed observations: 0.058340
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25982
#    Parameters : 2699
#    Iterations : 4
#          Time : 0.211308 [s]
#  Initial cost : 0.768622 [px]
#    Final cost : 0.757194 [px]
#   Termination : Convergence
#
#   => Merged observations: 41
#   => Completed observations: 76
#   => Filtered observations: 7
#   => Changed observations: 0.008468
#
# ==============================================================================
# Registering image #256 (256)
# ==============================================================================
#
#   => Image sees 1200 / 4157 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2424
#    Parameters : 6
#    Iterations : 19
#          Time : 0.0469649 [s]
#  Initial cost : 0.754142 [px]
#    Final cost : 0.729088 [px]
#   Termination : Convergence
#
#   => Continued observations: 1190
#   => Added observations: 728
#
# Bundle adjustment report
# ------------------------
#     Residuals : 26380
#    Parameters : 3017
#    Iterations : 26
#          Time : 1.49633 [s]
#  Initial cost : 0.693938 [px]
#    Final cost : 0.656143 [px]
#   Termination : No convergence
#
#   => Merged observations: 22
#   => Completed observations: 292
#   => Filtered observations: 352
#   => Changed observations: 0.044656
#
# Bundle adjustment report
# ------------------------
#     Residuals : 26802
#    Parameters : 2831
#    Iterations : 4
#          Time : 0.285312 [s]
#  Initial cost : 0.787525 [px]
#    Final cost : 0.775602 [px]
#   Termination : Convergence
#
#   => Merged observations: 12
#   => Completed observations: 92
#   => Filtered observations: 9
#   => Changed observations: 0.007474
#
# ==============================================================================
# Registering image #257 (257)
# ==============================================================================
#
#   => Image sees 1144 / 4064 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2344
#    Parameters : 6
#    Iterations : 10
#          Time : 0.0266211 [s]
#  Initial cost : 0.695582 [px]
#    Final cost : 0.689925 [px]
#   Termination : Convergence
#
#   => Continued observations: 1138
#   => Added observations: 972
#
# Bundle adjustment report
# ------------------------
#     Residuals : 26358
#    Parameters : 3173
#    Iterations : 26
#          Time : 1.55653 [s]
#  Initial cost : 0.680155 [px]
#    Final cost : 0.655615 [px]
#   Termination : No convergence
#
#   => Merged observations: 61
#   => Completed observations: 446
#   => Filtered observations: 266
#   => Changed observations: 0.052223
#
# Bundle adjustment report
# ------------------------
#     Residuals : 26280
#    Parameters : 3062
#    Iterations : 4
#          Time : 0.287196 [s]
#  Initial cost : 0.813972 [px]
#    Final cost : 0.802936 [px]
#   Termination : Convergence
#
#   => Merged observations: 17
#   => Completed observations: 60
#   => Filtered observations: 6
#   => Changed observations: 0.005621
#
# ==============================================================================
# Registering image #258 (258)
# ==============================================================================
#
#   => Image sees 1119 / 4006 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2276
#    Parameters : 6
#    Iterations : 12
#          Time : 0.030021 [s]
#  Initial cost : 0.711277 [px]
#    Final cost : 0.672101 [px]
#   Termination : Convergence
#
#   => Continued observations: 1114
#   => Added observations: 1078
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25662
#    Parameters : 3083
#    Iterations : 23
#          Time : 1.16017 [s]
#  Initial cost : 0.724759 [px]
#    Final cost : 0.687612 [px]
#   Termination : Convergence
#
#   => Merged observations: 30
#   => Completed observations: 466
#   => Filtered observations: 266
#   => Changed observations: 0.052530
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25780
#    Parameters : 2996
#    Iterations : 4
#          Time : 0.207216 [s]
#  Initial cost : 0.848422 [px]
#    Final cost : 0.836799 [px]
#   Termination : Convergence
#
#   => Merged observations: 24
#   => Completed observations: 63
#   => Filtered observations: 5
#   => Changed observations: 0.006316
#
# ==============================================================================
# Registering image #259 (259)
# ==============================================================================
#
#   => Image sees 1299 / 4357 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2648
#    Parameters : 6
#    Iterations : 7
#          Time : 0.037256 [s]
#  Initial cost : 0.630942 [px]
#    Final cost : 0.630424 [px]
#   Termination : Convergence
#
#   => Continued observations: 1295
#   => Added observations: 823
#
# Bundle adjustment report
# ------------------------
#     Residuals : 28182
#    Parameters : 3371
#    Iterations : 26
#          Time : 1.73403 [s]
#  Initial cost : 0.704591 [px]
#    Final cost : 0.675649 [px]
#   Termination : No convergence
#
#   => Merged observations: 89
#   => Completed observations: 268
#   => Filtered observations: 220
#   => Changed observations: 0.038380
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27976
#    Parameters : 3260
#    Iterations : 4
#          Time : 0.309049 [s]
#  Initial cost : 0.841384 [px]
#    Final cost : 0.833878 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 53
#   => Filtered observations: 3
#   => Changed observations: 0.003750
#
# ==============================================================================
# Registering image #260 (260)
# ==============================================================================
#
#   => Image sees 1290 / 4443 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2634
#    Parameters : 6
#    Iterations : 11
#          Time : 0.0281951 [s]
#  Initial cost : 0.621336 [px]
#    Final cost : 0.610789 [px]
#   Termination : Convergence
#
#   => Continued observations: 1285
#   => Added observations: 969
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29278
#    Parameters : 3410
#    Iterations : 26
#          Time : 1.18881 [s]
#  Initial cost : 0.681101 [px]
#    Final cost : 0.64998 [px]
#   Termination : No convergence
#
#   => Merged observations: 49
#   => Completed observations: 402
#   => Filtered observations: 176
#   => Changed observations: 0.040066
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27648
#    Parameters : 3353
#    Iterations : 4
#          Time : 0.219825 [s]
#  Initial cost : 0.856611 [px]
#    Final cost : 0.848293 [px]
#   Termination : Convergence
#
#   => Merged observations: 50
#   => Completed observations: 41
#   => Filtered observations: 4
#   => Changed observations: 0.006051
#
# ==============================================================================
# Registering image #261 (261)
# ==============================================================================
#
#   => Image sees 1325 / 4579 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2700
#    Parameters : 6
#    Iterations : 11
#          Time : 0.035815 [s]
#  Initial cost : 0.668788 [px]
#    Final cost : 0.609831 [px]
#   Termination : Convergence
#
#   => Continued observations: 1322
#   => Added observations: 1326
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27596
#    Parameters : 3803
#    Iterations : 23
#          Time : 1.04067 [s]
#  Initial cost : 0.712266 [px]
#    Final cost : 0.690569 [px]
#   Termination : Convergence
#
#   => Merged observations: 44
#   => Completed observations: 477
#   => Filtered observations: 180
#   => Changed observations: 0.045835
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27972
#    Parameters : 3746
#    Iterations : 4
#          Time : 0.218765 [s]
#  Initial cost : 0.880876 [px]
#    Final cost : 0.872792 [px]
#   Termination : Convergence
#
#   => Merged observations: 38
#   => Completed observations: 29
#   => Filtered observations: 7
# ...
#   => Completed observations: 31
#   => Filtered observations: 4
#   => Changed observations: 0.000869
#
# ==============================================================================
# Registering image #311 (311)
# ==============================================================================
#
#   => Image sees 2790 / 6669 points
#
# Pose refinement report
# ----------------------
#     Residuals : 5612
#    Parameters : 6
#    Iterations : 7
#          Time : 0.049829 [s]
#  Initial cost : 0.52273 [px]
#    Final cost : 0.517396 [px]
#   Termination : Convergence
#
#   => Continued observations: 2786
#   => Added observations: 2455
#
# Bundle adjustment report
# ------------------------
#     Residuals : 70264
#    Parameters : 8288
#    Iterations : 20
#          Time : 1.73056 [s]
#  Initial cost : 0.485026 [px]
#    Final cost : 0.465827 [px]
#   Termination : Convergence
#
#   => Merged observations: 81
#   => Completed observations: 875
#   => Filtered observations: 167
#   => Changed observations: 0.029586
#
# Bundle adjustment report
# ------------------------
#     Residuals : 71060
#    Parameters : 8216
#    Iterations : 4
#          Time : 0.41652 [s]
#  Initial cost : 0.564303 [px]
#    Final cost : 0.559005 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 22
#   => Filtered observations: 4
#   => Changed observations: 0.000678
#
# ==============================================================================
# Registering image #312 (312)
# ==============================================================================
#
#   => Image sees 2691 / 5995 points
#
# Pose refinement report
# ----------------------
#     Residuals : 5398
#    Parameters : 6
#    Iterations : 9
#          Time : 0.09797 [s]
#  Initial cost : 0.594024 [px]
#    Final cost : 0.525564 [px]
#   Termination : Convergence
#
#   => Continued observations: 2687
#   => Added observations: 2187
#
# Bundle adjustment report
# ------------------------
#     Residuals : 68564
#    Parameters : 7748
#    Iterations : 23
#          Time : 2.12499 [s]
#  Initial cost : 0.484819 [px]
#    Final cost : 0.47291 [px]
#   Termination : Convergence
#
#   => Merged observations: 20
#   => Completed observations: 901
#   => Filtered observations: 180
#   => Changed observations: 0.028733
#
# Bundle adjustment report
# ------------------------
#     Residuals : 69260
#    Parameters : 7697
#    Iterations : 4
#          Time : 0.406127 [s]
#  Initial cost : 0.57025 [px]
#    Final cost : 0.565363 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 39
#   => Filtered observations: 4
#   => Changed observations: 0.001112
#
# ==============================================================================
# Registering image #313 (313)
# ==============================================================================
#
#   => Image sees 2494 / 6112 points
#
# Pose refinement report
# ----------------------
#     Residuals : 5010
#    Parameters : 6
#    Iterations : 9
#          Time : 0.065408 [s]
#  Initial cost : 0.581891 [px]
#    Final cost : 0.56967 [px]
#   Termination : Convergence
#
#   => Continued observations: 2489
#   => Added observations: 1319
#
# Bundle adjustment report
# ------------------------
#     Residuals : 65546
#    Parameters : 6542
#    Iterations : 26
#          Time : 3.19697 [s]
#  Initial cost : 0.521252 [px]
#    Final cost : 0.494066 [px]
#   Termination : No convergence
#
#   => Merged observations: 12
#   => Completed observations: 728
#   => Filtered observations: 217
#   => Changed observations: 0.025778
#
# Bundle adjustment report
# ------------------------
#     Residuals : 65976
#    Parameters : 6455
#    Iterations : 4
#          Time : 0.616432 [s]
#  Initial cost : 0.589534 [px]
#    Final cost : 0.584884 [px]
#   Termination : Convergence
#
#   => Merged observations: 17
#   => Completed observations: 35
#   => Filtered observations: 1
#   => Changed observations: 0.001419
#
# ==============================================================================
# Registering image #314 (314)
# ==============================================================================
#
#   => Image sees 2274 / 5609 points
#
# Pose refinement report
# ----------------------
#     Residuals : 4582
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0435801 [s]
#  Initial cost : 0.583834 [px]
#    Final cost : 0.57163 [px]
#   Termination : Convergence
#
#   => Continued observations: 2268
#   => Added observations: 1138
#
# Bundle adjustment report
# ------------------------
#     Residuals : 62034
#    Parameters : 5237
#    Iterations : 19
#          Time : 1.41832 [s]
#  Initial cost : 0.51232 [px]
#    Final cost : 0.500843 [px]
#   Termination : Convergence
#
#   => Merged observations: 63
#   => Completed observations: 567
#   => Filtered observations: 183
#   => Changed observations: 0.022788
#
# Bundle adjustment report
# ------------------------
#     Residuals : 62584
#    Parameters : 5201
#    Iterations : 4
#          Time : 0.359731 [s]
#  Initial cost : 0.607532 [px]
#    Final cost : 0.602826 [px]
#   Termination : Convergence
#
#   => Merged observations: 29
#   => Completed observations: 22
#   => Filtered observations: 2
#   => Changed observations: 0.001474
#
# ==============================================================================
# Registering image #315 (315)
# ==============================================================================
#
#   => Image sees 1947 / 4212 points
#
# Pose refinement report
# ----------------------
#     Residuals : 3918
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0358489 [s]
#  Initial cost : 0.599285 [px]
#    Final cost : 0.589967 [px]
#   Termination : Convergence
#
#   => Continued observations: 1943
#   => Added observations: 1382
#
# Bundle adjustment report
# ------------------------
#     Residuals : 57556
#    Parameters : 4937
#    Iterations : 22
#          Time : 1.697 [s]
#  Initial cost : 0.522976 [px]
#    Final cost : 0.509334 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 783
#   => Filtered observations: 205
#   => Changed observations: 0.029980
#
# Bundle adjustment report
# ------------------------
#     Residuals : 57914
#    Parameters : 4859
#    Iterations : 4
#          Time : 0.474656 [s]
#  Initial cost : 0.621292 [px]
#    Final cost : 0.616294 [px]
#   Termination : Convergence
#
#   => Merged observations: 14
#   => Completed observations: 48
#   => Filtered observations: 5
#   => Changed observations: 0.002021
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 58
#   => Merged observations: 0
#   => Retriangulated observations: 1050
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.260127e+06    0.00e+00    4.12e+06   0.00e+00   0.00e+00  1.00e+04        0    2.17e+00    1.19e+01
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 1.5582e+09
#     Nonzeros in L:       1.5285e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       5.0
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 1.5582e+09
#         nnz(L):     1.5285e+06
#   OK
#    1  1.108154e+06    1.52e+05    1.10e+06   2.52e+01   8.99e-01  2.04e+04        1    1.25e+01    2.44e+01
#    2  1.091533e+06    1.66e+04    2.69e+05   2.31e+01   9.95e-01  6.12e+04        1    9.93e+00    3.43e+01
#    3  1.088396e+06    3.14e+03    7.12e+04   1.52e+01   1.00e+00  1.83e+05        1    9.28e+00    4.36e+01
#    4  1.087052e+06    1.34e+03    4.41e+04   9.84e+00   9.92e-01  5.50e+05        1    8.26e+00    5.18e+01
#    5  1.086737e+06    3.15e+02    9.17e+03   7.14e+00   9.92e-01  1.65e+06        1    1.02e+01    6.20e+01
#    6  1.086712e+06    2.56e+01    1.17e+04   1.01e+01   8.69e-01  2.76e+06        1    8.16e+00    7.02e+01
#    7  1.086705e+06    6.25e+00    4.42e+03   1.17e+01   9.17e-01  6.57e+06        1    9.38e+00    7.96e+01
#    8  1.086704e+06    9.64e-01    8.58e+02   1.15e+01   9.79e-01  1.97e+07        1    9.64e+00    8.92e+01
#    9  1.086704e+06    5.07e-02    1.13e+02   7.13e+00   1.02e+00  5.91e+07        1    7.96e+00    9.72e+01
#   10  1.086704e+06    1.00e-03    2.71e+01   1.99e+00   1.07e+00  1.77e+08        1    9.96e+00    1.07e+02
#   11  1.086704e+06    1.95e-05    6.45e+00   2.17e-01   1.16e+00  5.32e+08        1    9.40e+00    1.17e+02
#   12  1.086704e+06    6.90e-06    1.85e+00   3.21e-02   1.02e+00  1.60e+09        1    7.94e+00    1.24e+02
#   13  1.086704e+06    1.85e-05    1.85e+00   7.39e-02   9.99e-01  4.79e+09        1    9.91e+00    1.34e+02
#   14  1.086704e+06    5.47e-05    2.00e+00   2.20e-01   1.00e+00  1.44e+10        1    8.48e+00    1.43e+02
#   15  1.086704e+06    1.58e-04    2.00e+00   6.44e-01   1.00e+00  4.31e+10        1    9.34e+00    1.52e+02
#   16  1.086704e+06    4.22e-04    1.56e+01   1.80e+00   9.99e-01  1.29e+11        1    9.87e+00    1.62e+02
#   17  1.086704e+06    9.08e-04    9.53e+01   4.47e+00   9.86e-01  3.88e+11        1    8.20e+00    1.70e+02
#   18  1.086704e+06    1.08e-03    3.18e+02   8.17e+00   8.76e-01  6.75e+11        1    9.94e+00    1.80e+02
#   19  1.086704e+06    6.42e-04    2.13e+02   6.69e+00   9.02e-01  1.41e+12        1    9.73e+00    1.90e+02
#   20  1.086704e+06    2.01e-04    8.07e+01   4.12e+00   9.53e-01  4.22e+12        1    7.71e+00    1.98e+02
#   21  1.086704e+06    2.30e-05    1.07e+01   1.50e+00   9.93e-01  1.26e+13        1    1.02e+01    2.08e+02
#   22  1.086704e+06    3.70e-07    1.95e+00   1.97e-01   9.98e-01  3.79e+13        1    9.86e+00    2.18e+02
#   23  1.086704e+06    1.84e-08    1.09e-02   8.99e-03   3.98e+01  1.14e+14        1    7.72e+00    2.25e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2197138
#    Parameters : 326110
#    Iterations : 24
#          Time : 225.633 [s]
#  Initial cost : 0.757318 [px]
#    Final cost : 0.703278 [px]
#   Termination : Convergence
#
#   => Completed observations: 1257
#   => Merged observations: 862
#   => Filtered observations: 1824
#   => Changed observations: 0.003589
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  9.197829e+05    0.00e+00    1.17e+06   0.00e+00   0.00e+00  1.00e+04        0    2.41e+00    1.36e+01
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 1.535e+09
#     Nonzeros in L:       1.5163e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       5.0
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 1.535e+09
#         nnz(L):     1.5163e+06
#   OK
#    1  9.095015e+05    1.03e+04    2.26e+05   2.48e+00   9.98e-01  3.00e+04        1    1.35e+01    2.71e+01
#    2  9.080865e+05    1.41e+03    6.20e+04   2.60e+00   9.98e-01  9.00e+04        1    7.73e+00    3.48e+01
#    3  9.068132e+05    1.27e+03    9.91e+03   4.64e+00   9.97e-01  2.70e+05        1    1.00e+01    4.48e+01
#    4  9.061518e+05    6.61e+02    9.51e+03   3.45e+00   9.98e-01  8.10e+05        1    8.92e+00    5.38e+01
#    5  9.060327e+05    1.19e+02    1.21e+04   2.74e+00   9.98e-01  2.43e+06        1    8.59e+00    6.23e+01
#    6  9.060247e+05    7.93e+00    7.55e+03   4.52e+00   8.58e-01  3.84e+06        1    9.89e+00    7.22e+01
#    7  9.060227e+05    2.04e+00    1.50e+03   2.06e+00   9.77e-01  1.15e+07        1    8.17e+00    8.04e+01
#    8  9.060226e+05    1.17e-01    1.77e+02   7.08e-01   1.00e+00  3.45e+07        1    9.87e+00    9.03e+01
#    9  9.060226e+05    1.92e-03    5.05e+00   9.52e-02   1.03e+00  1.04e+08        1    9.66e+00    9.99e+01
#   10  9.060226e+05    1.20e-05    2.00e+00   1.03e-02   1.05e+00  3.11e+08        1    7.88e+00    1.08e+02
#   11  9.060226e+05    9.75e-06    1.98e+00   2.25e-02   1.00e+00  9.32e+08        1    9.98e+00    1.18e+02
#   12  9.060226e+05    2.90e-05    9.66e-01   6.74e-02   9.99e-01  2.80e+09        1    9.75e+00    1.28e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2195784
#    Parameters : 325354
#    Iterations : 13
#          Time : 127.721 [s]
#  Initial cost : 0.647214 [px]
#    Final cost : 0.642354 [px]
#   Termination : Convergence
#
#   => Completed observations: 586
#   => Merged observations: 175
#   => Filtered observations: 287
#   => Changed observations: 0.000955
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  9.068331e+05    0.00e+00    1.20e+05   0.00e+00   0.00e+00  1.00e+04        0    2.04e+00    1.23e+01
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 1.5513e+09
#     Nonzeros in L:       1.5239e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       5.0
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 1.5513e+09
#         nnz(L):     1.5239e+06
#   OK
#    1  9.061419e+05    6.91e+02    1.84e+04   3.58e-01   9.99e-01  3.00e+04        1    1.43e+01    2.66e+01
#    2  9.061135e+05    2.84e+01    2.12e+03   5.06e-01   1.00e+00  9.00e+04        1    9.81e+00    3.65e+01
#    3  9.060845e+05    2.89e+01    1.28e+03   8.40e-01   1.00e+00  2.70e+05        1    7.93e+00    4.44e+01
#    4  9.060685e+05    1.61e+01    3.50e+02   4.96e-01   1.00e+00  8.10e+05        1    1.00e+01    5.44e+01
#    5  9.060652e+05    3.23e+00    1.83e+02   6.35e-01   1.00e+00  2.43e+06        1    9.40e+00    6.38e+01
#    6  9.060648e+05    3.87e-01    4.18e+02   1.10e+00   9.91e-01  7.29e+06        1    8.88e+00    7.27e+01
#    7  9.060648e+05    5.09e-02    1.16e+02   5.76e-01   1.00e+00  2.19e+07        1    1.04e+01    8.31e+01
#    8  9.060648e+05    1.87e-03    6.80e+00   1.13e-01   1.03e+00  6.56e+07        1    9.42e+00    9.25e+01
#    9  9.060648e+05    1.55e-05    1.98e+00   9.96e-03   1.06e+00  1.97e+08        1    8.24e+00    1.01e+02
#   10  9.060648e+05    1.27e-06    6.21e-01   6.25e-03   1.01e+00  5.90e+08        1    9.90e+00    1.11e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2196286
#    Parameters : 325276
#    Iterations : 11
#          Time : 110.783 [s]
#  Initial cost : 0.642568 [px]
#    Final cost : 0.642296 [px]
#   Termination : Convergence
#
#   => Completed observations: 187
#   => Merged observations: 53
#   => Filtered observations: 92
#   => Changed observations: 0.000302
#   => Filtered images: 0
#
# Elapsed time: 164.428 [minutes]

# %% [markdown]
# Convert the sparse reconstruction to text format (camera poses and 3D points)

# %%
# !mkdir -p /content/drive/MyDrive/colmap_project/sparse_text
# !colmap model_converter \
    --input_path /content/drive/MyDrive/colmap_project/sparse/0 \
    --output_path /content/drive/MyDrive/colmap_project/sparse_text \
    --output_type TXT
